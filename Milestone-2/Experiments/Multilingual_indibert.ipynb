# %%
# !pip install transformers
# !pip install -U -q PyDrive
# !pip install simpletransformers
# !pip freeze | grep simpletransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 102.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 92.6 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 25.8 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.28.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting simpletransformers
#   Downloading simpletransformers-0.63.9-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.5/250.5 kB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (1.10.1)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (4.65.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (1.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (2.27.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (2.12.2)
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 40.7 MB/s eta 0:00:00
# Collecting streamlit
#   Downloading streamlit-1.21.0-py2.py3-none-any.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 93.9 MB/s eta 0:00:00
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.2 MB/s eta 0:00:00
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting wandb>=0.10.32
#   Downloading wandb-0.15.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 92.3 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (1.2.2)
# Requirement already satisfied: transformers>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (4.28.1)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (0.13.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (2022.10.31)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.6.0->simpletransformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers>=4.6.0->simpletransformers) (3.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.6.0->simpletransformers) (23.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.6.0->simpletransformers) (0.13.4)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.10.32->simpletransformers) (5.9.5)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.10.32->simpletransformers) (1.4.4)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.10.32->simpletransformers) (8.1.3)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting GitPython!=3.1.29,>=1.0.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 24.7 MB/s eta 0:00:00
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.20.0-py2.py3-none-any.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.8/198.8 kB 25.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from wandb>=0.10.32->simpletransformers) (4.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from wandb>=0.10.32->simpletransformers) (67.6.1)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.15.0 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.10.32->simpletransformers) (3.20.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers) (1.26.15)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 15.3 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 79.3 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets->simpletransformers) (9.0.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 25.4 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets->simpletransformers) (2023.4.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->simpletransformers) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->simpletransformers) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->simpletransformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->simpletransformers) (3.1.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (6.4.1)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (5.3.0)
# Collecting watchdog
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 9.5 MB/s eta 0:00:00
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 67.2 MB/s eta 0:00:00
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (6.2)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 17.0 MB/s eta 0:00:00
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: toml in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (0.10.2)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (4.3)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (13.3.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (8.4.0)
# Requirement already satisfied: altair<5,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (4.2.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (0.7.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (1.53.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (1.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (1.4.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (0.40.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (3.1.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (4.3.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from docker-pycreds>=0.4.0->wandb>=0.10.32->simpletransformers) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets->simpletransformers) (23.1.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 16.3 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 21.3 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.3/269.3 kB 30.5 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=1.4->streamlit->simpletransformers) (3.15.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.11.0->streamlit->simpletransformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.11.0->streamlit->simpletransformers) (2.14.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.9/dist-packages (from tzlocal>=1.1->streamlit->simpletransformers) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.9/dist-packages (from validators>=0.2->streamlit->simpletransformers) (4.4.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard->simpletransformers) (2.1.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit->simpletransformers) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit->simpletransformers) (0.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (3.2.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.9/dist-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit->simpletransformers) (2023.3)
# Building wheels for collected packages: seqeval, validators, pathtools
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=90aa914f57aa9143c9525c6f442829db709ab31ee98318ed3f34bb425efc70a9
#   Stored in directory: /root/.cache/pip/wheels/e2/a5/92/2c80d1928733611c2747a9820e1324a6835524d9411510c142
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=e58e15fd469b71189ac971caf95b2121941de13851b954bd6f549cdf831f5b5c
#   Stored in directory: /root/.cache/pip/wheels/2d/f0/a8/1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=a3cfaa8afba8141c4dbd7c98042b78335e26d1a5c068fcaf5b0161d47ce73ff4
#   Stored in directory: /root/.cache/pip/wheels/b7/0a/67/ada2a22079218c75a88361c0782855cc72aebc4d18d0289d05
# Successfully built seqeval validators pathtools
# Installing collected packages: sentencepiece, pathtools, xxhash, watchdog, validators, smmap, setproctitle, sentry-sdk, pympler, multidict, frozenlist, docker-pycreds, dill, blinker, async-timeout, yarl, responses, pydeck, multiprocess, gitdb, aiosignal, seqeval, GitPython, aiohttp, wandb, streamlit, datasets, simpletransformers
# Successfully installed GitPython-3.1.31 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 blinker-1.6.2 datasets-2.11.0 dill-0.3.6 docker-pycreds-0.4.0 frozenlist-1.3.3 gitdb-4.0.10 multidict-6.0.4 multiprocess-0.70.14 pathtools-0.1.2 pydeck-0.8.1b0 pympler-1.0.1 responses-0.18.0 sentencepiece-0.1.98 sentry-sdk-1.20.0 seqeval-1.2.2 setproctitle-1.3.2 simpletransformers-0.63.9 smmap-5.0.0 streamlit-1.21.0 validators-0.20.0 wandb-0.15.0 watchdog-3.0.0 xxhash-3.2.0 yarl-1.9.1
# simpletransformers==0.63.9

# %%
import pandas as pd
df=pd.read_csv('/content/eng_3_train.tsv', delimiter='\t') 
df=df[["text", "category"]]
df = df.dropna()
df_dev=pd.read_csv('/content/eng_3_dev.tsv', delimiter='\t') 
df_dev=df_dev[["text", "category"]]
df_dev = df_dev.dropna()
df_test=pd.read_csv('/content/eng_3_test.tsv', delimiter='\t')
df_test = df_test.rename(columns={'text                        ': 'text'}) 
df_test = df_test.dropna()

# %%
import pandas as pd
tam_df=pd.read_csv('/content/tam_3_train.tsv', delimiter='\t') 
tam_df=tam_df[["text", "category"]]
tam_df = tam_df.dropna()
tam_df_dev=pd.read_csv('/content/tam_3_dev.tsv', delimiter='\t') 
tam_df_dev=tam_df_dev[["text", "category"]]
tam_df_dev = tam_df_dev.dropna()
tam_df_test=pd.read_csv('/content/tam_3_test.tsv', delimiter='\t')
tam_df_test = tam_df_test.rename(columns={'text                        ': 'text'}) 
tam_df_test = tam_df_test.dropna()

# %%
etdf=pd.read_csv('/content/eng_tam_train.tsv', delimiter='\t') 
etdf=etdf[["text", "category"]]
etdf = etdf.dropna()
etdf_dev=pd.read_csv('/content/eng_tam_dev.tsv', delimiter='\t') 
etdf_dev=etdf_dev[["text", "category"]]
etdf_dev = etdf_dev.dropna()
etdf_test=pd.read_csv('/content/eng_tam_test.tsv', delimiter='\t') 
etdf_test = etdf_test.dropna()

# %%
tedf=pd.read_csv('/content/tam_eng_train.tsv', delimiter='\t') 
tedf=tedf[["text", "category"]]
tedf = tedf.dropna()
tedf_dev=pd.read_csv('/content/tam_eng_dev.tsv', delimiter='\t') 
tedf_dev=tedf_dev[["text", "category"]]
tedf_dev = tedf_dev.dropna()
tedf_test=pd.read_csv('/content/tam_eng_test.tsv', delimiter='\t') 
tedf_test = tedf_test.dropna()

# %%
teldf=pd.read_csv('/content/eng_tel_train.tsv', delimiter='\t') 
teldf=teldf[["text", "category"]]
teldf = teldf.dropna()
teldf_dev=pd.read_csv('/content/eng_tel_dev.tsv', delimiter='\t') 
teldf_dev=teldf_dev[["text", "category"]]
teldf_dev = teldf_dev.dropna()
teldf_test=pd.read_csv('/content/eng_tel_test.tsv', delimiter='\t') 
teldf_test = teldf_test.dropna()

# %%
hieldf=pd.read_csv('/content/eng_hin_train.tsv', delimiter='\t') 
hieldf=hieldf[["text", "category"]]
hieldf = hieldf.dropna()
hieldf_dev=pd.read_csv('/content/eng_hin_dev.tsv', delimiter='\t') 
hieldf_dev=hieldf_dev[["text", "category"]]
hieldf_dev = hieldf_dev.dropna()
hieldf_test=pd.read_csv('/content/eng_hin_test.tsv', delimiter='\t') 
hieldf_test = hieldf_test.dropna()

# %%
mleldf=pd.read_csv('/content/eng_ml_train.tsv', delimiter='\t') 
mleldf=mleldf[["text", "category"]]
mleldf = mleldf.dropna()
mleldf_dev=pd.read_csv('/content/eng_ml_dev.tsv', delimiter='\t') 
mleldf_dev=mleldf_dev[["text", "category"]]
mleldf_dev = mleldf_dev.dropna()
mleldf_test=pd.read_csv('/content/eng_ml_test.tsv', delimiter='\t') 
mleldf_test = mleldf_test.dropna()

# %%
tamteldf=pd.read_csv('/content/tam_tel_train.tsv', delimiter='\t') 
tamteldf=tamteldf[["text", "category"]]
tamteldf = tamteldf.dropna()
tamteldf_dev=pd.read_csv('/content/tam_tel_dev.tsv', delimiter='\t') 
tamteldf_dev=tamteldf_dev[["text", "category"]]
tamteldf_dev = tamteldf_dev.dropna()
tamteldf_test=pd.read_csv('/content/tam_tel_test.tsv', delimiter='\t') 
tamteldf_test = tamteldf_test.dropna()

# %%
tamhieldf=pd.read_csv('/content/tam_hin_train.tsv', delimiter='\t') 
tamhieldf=tamhieldf[["text", "category"]]
tamhieldf = tamhieldf.dropna()
tamhieldf_dev=pd.read_csv('/content/tam_hin_dev.tsv', delimiter='\t') 
tamhieldf_dev=tamhieldf_dev[["text", "category"]]
tamhieldf_dev = tamhieldf_dev.dropna()
tamhieldf_test=pd.read_csv('/content/tam_hin_test.tsv', delimiter='\t') 
tamhieldf_test = tamhieldf_test.dropna()

# %%
tammleldf=pd.read_csv('/content/tam_ml_train.tsv', delimiter='\t') 
tammleldf=tammleldf[["text", "category"]]
tammleldf = tammleldf.dropna()
tammleldf_dev=pd.read_csv('/content/tam_ml_dev.tsv', delimiter='\t') 
tammleldf_dev=tammleldf_dev[["text", "category"]]
tammleldf_dev = tammleldf_dev.dropna()
tammleldf_test=pd.read_csv('/content/tam_ml_test.tsv', delimiter='\t') 
tammleldf_test = tammleldf_test.dropna()

# %%
train = pd.concat([df, tedf,tam_df,etdf,teldf,hieldf,mleldf,tamteldf,tammleldf])
valid = pd.concat([df_dev, tedf_dev,tam_df_dev,etdf_dev,teldf_dev,hieldf_dev,mleldf_dev,tamteldf_dev,tamhieldf_dev,tammleldf_dev])
test = pd.concat([df_test, tedf_test,tam_df_test,etdf_test,teldf_test,hieldf_test,mleldf_test,tamteldf_test,tamhieldf_test,tammleldf_test])

# %%
concatenated = pd.concat([train,test,valid])

import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit

df = concatenated

X = df['text']
y = df['category']

testsplit = StratifiedShuffleSplit(n_splits=1, test_size=0.20, random_state=42)

train_val_idx, test_idx = next(testsplit.split(X, y))

X_train_val, X_test = X.iloc[train_val_idx], X.iloc[test_idx]
y_train_val, y_test = y.iloc[train_val_idx], y.iloc[test_idx]


validsplit = StratifiedShuffleSplit(n_splits=1, test_size=0.25, random_state=42)

train_idx, val_idx = next(validsplit.split(X_train_val, y_train_val))

X_train, X_val = X_train_val.iloc[train_idx], X_train_val.iloc[val_idx]
y_train, y_val = y_train_val.iloc[train_idx], y_train_val.iloc[val_idx]

train_df = pd.DataFrame({'text': X_train, 'category': y_train})
val_df = pd.DataFrame({'text': X_val, 'category': y_val})
test_df = pd.DataFrame({'text': X_test, 'category': y_test})

print(f'Training set shape: {train_df.shape}')
print(f'Validation set shape: {val_df.shape}')
print(f'Test set shape: {test_df.shape}')
# Out:
# Training set shape: (25185, 2)
# Validation set shape: (8396, 2)
# Test set shape: (8396, 2)

# %%
print(train_df['category'].value_counts())
print(val_df['category'].value_counts())
print(test_df['category'].value_counts())
# Out:
# Non-anti-LGBT+ content    21955
# Homophobic                 2620
# Transphobic                 610
# Name: category, dtype: int64
# Non-anti-LGBT+ content    7319
# Homophobic                 873
# Transphobic                204
# Name: category, dtype: int64
# Non-anti-LGBT+ content    7319
# Homophobic                 874
# Transphobic                203
# Name: category, dtype: int64

# %%
train_df['category'] = train_df['category'].replace('Non-anti-LGBT+ content', 'ally')
val_df['category'] = val_df['category'].replace('Non-anti-LGBT+ content', 'ally')
test_df['category'] = test_df['category'].replace('Non-anti-LGBT+ content', 'ally')

# %%
train_df['category'] = train_df['category'].replace('ally', 0)
train_df['category'] = train_df['category'].replace('Homophobic', 1)
train_df['category'] = train_df['category'].replace('Transphobic', 2)

# %%
val_df['category'] = val_df['category'].replace('ally', 0)
val_df['category'] = val_df['category'].replace('Homophobic', 1)
val_df['category'] = val_df['category'].replace('Transphobic', 2)

# %%
test_df['category'] = test_df['category'].replace('ally', 0)
test_df['category'] = test_df['category'].replace('Homophobic', 1)
test_df['category'] = test_df['category'].replace('Transphobic', 2)

# %%
train_df=train_df[["text", "category"]]
train_df = train_df.rename(columns={'text': 'text', 'category': 'labels'})
val_df=val_df[["text", "category"]]
val_df = val_df.rename(columns={'text': 'text', 'category': 'labels'})
test_df=test_df[["text", "category"]]
test_df = test_df.rename(columns={'text': 'text', 'category': 'labels'})

# %%
# !pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emoji
#   Downloading emoji-2.2.0.tar.gz (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234926 sha256=4a6b3fca44b07f1846de1af0097828e5c87ee0bf327d520346d165e4fd6d9553
#   Stored in directory: /root/.cache/pip/wheels/9a/b8/0f/f580817231cbf59f6ade9fd132ff60ada1de9f7dc85521f857
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-2.2.0

# %%
import emoji
train_df['text'] = train_df['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))
val_df['text'] = val_df['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))
test_df['text'] = test_df['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))

# %% [markdown]
# Mbert on whole translated data

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs
import logging

logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

# define hyperparameter
train_args ={"reprocess_input_data": True,
             "overwrite_output_dir": True,
             "fp16":False,
             "num_train_epochs": 3,
             "max_seq_length": 128,
             "train_batch_size": 16,
             "eval_batch_size": 16,
             "logging_steps": 50,
             "save_steps": 2000,
             "learning_rate": 2e-5}

# Create a ClassificationModel
model = ClassificationModel(
    "albert", "ai4bharat/indic-bert",
    num_labels=3,
    args=train_args
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/507 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/135M [00:00<?, ?B/s]
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.bias', 'predictions.decoder.bias', 'sop_classifier.classifier.weight', 'predictions.dense.weight', 'predictions.LayerNorm.bias', 'predictions.LayerNorm.weight', 'predictions.decoder.weight', 'predictions.dense.bias', 'sop_classifier.classifier.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/5.65M [00:00<?, ?B/s]

# %%
model.train_model(train_df)
# Out:
#   0%|          | 0/25185 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/3 [00:00<?, ?it/s]
# Running Epoch 0 of 3:   0%|          | 0/1575 [00:00<?, ?it/s]
# Running Epoch 1 of 3:   0%|          | 0/1575 [00:00<?, ?it/s]
# Running Epoch 2 of 3:   0%|          | 0/1575 [00:00<?, ?it/s]
# (4725, 0.28396710043869144)

# %%
model.save_model('/content/xlm-mbert_model')

# %%
from sklearn.metrics import f1_score, accuracy_score

def f1_multiclass(labels, preds):
    return f1_score(labels, preds, average='macro')
result, model_outputs, wrong_predictions = model.eval_model(val_df, f1=f1_multiclass, acc=accuracy_score)
result
# Out:
#   0%|          | 0/8396 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/525 [00:00<?, ?it/s]
# {'mcc': 0.5524875068997764,
#  'f1': 0.6429094292803971,
#  'acc': 0.9068604097189138,
#  'eval_loss': 0.34232132727723746}

# %%
test_df
# Out:
#                                                    text  labels
# 1510  Part 2 When will pro come my rose rose rose my...       0
# 189      பெண்மை புதுமை முதுமை தாய்மை அவன் அல்ல அவள்தான்       0
# 2621               ఇది చాలా తప్పు. కోడ్‌కి డిటెస్టపైల్.       1
# 1829                                    S, మీరు చూడండి?       0
# 755   What is Madan Dravidian? Dravidam. What happen...       0
# ...                                                 ...     ...
# 556   Even if nature does not change, great dangers ...       1
# 1209  स्प्र्र अन्ना दिल को छू लेने वाली... सभी के लि...       0
# 692   सौम्या नारायण कृपया बेवकूफ संस्कृति के बजाय प्...       0
# 2648  இன்னும் கல்லகாதல் மற்றும் கற்பலிப்பு  அதிகரிக்...       1
# 2465                           కన్నీళ్లతో ఐస్ పైలట్_వేట       0
#
# [8396 rows x 2 columns]

# %%
test = test_df['text'].tolist()
labels = test_df['labels'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/8396 [00:00<?, ?it/s]
#   0%|          | 0/525 [00:00<?, ?it/s]
#                                                   text  true_label  \
# 0                 ఇది చాలా తప్పు. కోడ్‌కి డిటెస్టపైల్.           1
# 1                     नन परमचर्यम पर निर्भर थीं। आप...           1
# 2                                        ఇది అంగమైంది.           0
# 3    நான் கொஞ்சம் நேரம் உன் பேச்ச கேட்டேன், என்னயவே...           1
# 4                 സമൂഹത്തെ മാറ്റാത്തതിൽ നാം ലജ്ജിക്കണം           1
# ..                                                 ...         ...
# 791                        Your life is in your hands.           1
# 792  హే, నువ్వు చిన్న పిల్లవి. అభిరామి నాయుడు ఎవరో ...           0
# 793  ഒരു പുരുഷനും പെണ്ണിനൊപ്പം ജീവിക്കാൻ ആഗ്രഹിക്കാ...           1
# 794  weird தமிழன்  அறிவை கொஞ்சம் வளர்த்துக்கோங்க  ஓ...           1
# 795                 ஆண்மை. பாவம் பாவம். நீதிமன்றம்????           1
#
#      predicted_label
# 0                  0
# 1                  0
# 2                  1
# 3                  0
# 4                  0
# ..               ...
# 791                0
# 792                1
# 793                0
# 794                0
# 795                0
#
# [796 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.94      0.97      0.95      7319
#   homophobic       0.65      0.55      0.60       874
#  transphobic       0.43      0.21      0.28       203
#
#     accuracy                           0.91      8396
#    macro avg       0.67      0.58      0.61      8396
# weighted avg       0.89      0.91      0.90      8396

# %% [markdown]
# #testing with Hindi

# %%
o_test=pd.read_csv('/content/eng_hin_test.tsv', delimiter='\t') 
o_test = o_test.dropna()
e_test=pd.read_csv('/content/tam_hin_test.tsv', delimiter='\t')
e_test=e_test[["text", "category"]] 
e_test = e_test.dropna()

# %%
test_ml = pd.concat([o_test,e_test])
len(test_ml)
# Out:
# 1819

# %%
test_ml['category'] = test_ml['category'].replace('Non-anti-LGBT+ content', 'ally')
test_ml['category'] = test_ml['category'].replace('ally', 0)
test_ml['category'] = test_ml['category'].replace('Homophobic', 1)
test_ml['category'] = test_ml['category'].replace('Transphobic', 2)

# %%
test_ml=test_ml[["text", "category"]]
test_ml = test_ml.rename(columns={'text': 'text', 'category': 'labels'})

# %%
test_ml['text'] = test_ml['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))

# %%
test = test_ml['text'].tolist()
labels = test_ml['labels'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/1819 [00:00<?, ?it/s]
#   0%|          | 0/114 [00:00<?, ?it/s]
#                                                   text  true_label  \
# 0    आप दोनों जिन्होंने मेरी टिप्पणी का जवाब दिया, ...           1
# 1                       पुलिस को उन्हें सजा देनी चाहिए           1
# 2                       उत्सर्जन बेवकूफों वहाँ मत खेलो           2
# 3    यदि किसी परामर्श की आवश्यकता है, तो आपको इसे प...           1
# 4                               यह तो बड़ी बुरी बात है           0
# ..                                                 ...         ...
# 113  अरवनिया कोल्लन भी एक ऐसा कुत्ता है जो भीख मांग...           2
# 114    अनाथ क्यों बड़े होते हैं आपकी तरह लेस्बियन, गे?           1
# 115  आप बौद्धिक रूप से बोलने के बारे में सोचते हैं ...           1
# 116  उत्कृष्ट व्याख्या तमिल में सुनी गई। सबसे बड़े ...           0
# 117  सुंदर वाणी मधुर वाणी। सवाल का जवाब बहुत अच्छा ...           1
#
#      predicted_label
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  1
# ..               ...
# 113                1
# 114                0
# 115                0
# 116                1
# 117                0
#
# [118 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.96      0.98      0.97      1579
#   homophobic       0.75      0.71      0.73       194
#  transphobic       0.78      0.39      0.52        46
#
#     accuracy                           0.94      1819
#    macro avg       0.83      0.69      0.74      1819
# weighted avg       0.93      0.94      0.93      1819

# %% [markdown]
# # testing with Telugu

# %%
o_test=pd.read_csv('/content/eng_tel_test.tsv', delimiter='\t') 
o_test = o_test.dropna()
e_test=pd.read_csv('/content/tam_tel_test.tsv', delimiter='\t')
e_test=e_test[["text", "category"]] 
e_test = e_test.dropna()

# %%
test_ml = pd.concat([o_test,e_test])
len(test_ml)
# Out:
# 1819

# %%
test_ml['category'] = test_ml['category'].replace('Non-anti-LGBT+ content', 'ally')
test_ml['category'] = test_ml['category'].replace('ally', 0)
test_ml['category'] = test_ml['category'].replace('Homophobic', 1)
test_ml['category'] = test_ml['category'].replace('Transphobic', 2)

# %%
test_ml=test_ml[["text", "category"]]
test_ml = test_ml.rename(columns={'text': 'text', 'category': 'labels'})

# %%
test_ml['text'] = test_ml['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))

# %%
test = test_ml['text'].tolist()
labels = test_ml['labels'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/1819 [00:00<?, ?it/s]
#   0%|          | 0/114 [00:00<?, ?it/s]
#                                                   text  true_label  \
# 0    సంస్కృతి గురించి మాట్లాడే వారికి, వివాహానికి మ...           0
# 1    నా వ్యాఖ్యకు ప్రత్యుత్తరం ఇచ్చిన మీరిద్దరూ దీన...           1
# 2    సత్య నారాయణన్ , నేటికీ పాశ్చాత్య ప్రపంచంలో దీన...           1
# 3    నా అభిప్రాయం .. ఇది మానసిక వ్యాధి. వెళ్లి వైద్...           1
# 4     ఇది చట్టబద్ధం చేయబడినందున అది సరైనదని అర్థం కాదు           0
# ..                                                 ...         ...
# 115  మిత్రమా, పంటి నోటికి కావాల్సిన వంకాయను ఎందుకు ...           0
# 116        మీరు తెలివిగా మాట్లాడాలని అనుకుంటున్నారు...           1
# 117  ఆమె చాలా చక్కగా నటిస్తుంది. మంచూర్‌లో డబ్బులు ...           2
# 118                  ఏ అబ్బాయి కూడా అబ్బాయిగా ఉండకూడదు           0
# 119  చక్కని ప్రసంగం. మధురమైన స్వరం. అన్న ప్రశ్నకు స...           1
#
#      predicted_label
# 0                  1
# 1                  0
# 2                  0
# 3                  0
# 4                  1
# ..               ...
# 115                1
# 116                0
# 117                0
# 118                1
# 119                0
#
# [120 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.95      0.98      0.97      1579
#   homophobic       0.78      0.67      0.72       194
#  transphobic       0.72      0.39      0.51        46
#
#     accuracy                           0.93      1819
#    macro avg       0.82      0.68      0.73      1819
# weighted avg       0.93      0.93      0.93      1819

# %% [markdown]
# # testing with Malyalam

# %%
o_test=pd.read_csv('/content/eng_ml_test.tsv', delimiter='\t') 
o_test = o_test.dropna()
e_test=pd.read_csv('/content/tam_ml_test.tsv', delimiter='\t')
e_test=e_test[["text", "category"]] 
e_test = e_test.dropna()

# %%
test_ml = pd.concat([o_test,e_test])
len(test_ml)
# Out:
# 1819

# %%
test_ml['category'] = test_ml['category'].replace('Non-anti-LGBT+ content', 'ally')
test_ml['category'] = test_ml['category'].replace('ally', 0)
test_ml['category'] = test_ml['category'].replace('Homophobic', 1)
test_ml['category'] = test_ml['category'].replace('Transphobic', 2)

# %%
test_ml=test_ml[["text", "category"]]
test_ml = test_ml.rename(columns={'text': 'text', 'category': 'labels'})

# %%
test_ml['text'] = test_ml['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))

# %%
test = test_ml['text'].tolist()
labels = test_ml['labels'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/1819 [00:00<?, ?it/s]
#   0%|          | 0/114 [00:00<?, ?it/s]
#                                                  text  true_label  \
# 0   എന്റെ അഭിപ്രായത്തിന് മറുപടി നൽകിയ നിങ്ങൾ രണ്ടു...           1
# 1   സത്യ നാരായണൻ , ഇന്നും പാശ്ചാത്യലോകത്ത് ഇത് പ്ര...           1
# 2   ഇത്തരം പ്രവർത്തനങ്ങൾക്കെതിരെ നടപടിയെടുക്കാൻ ഞാ...           0
# 3   ഞങ്ങൾ റെയിൽവേ പോലീസാണ് ഓ, ക്ഷമിക്കണം, അവർ ഉറങ്...           1
# 4   അവർ ആണും പെണ്ണുമല്ല..മാനസിക വിഭ്രാന്തിയുള്ള ചി...           1
# ..                                                ...         ...
# 93  പ്രകൃതി മനുഷ്യനെ സൃഷ്ടിക്കാൻ,,; മനുഷ്യൻ പണം സൃ...           0
# 94                                    രോഷാകുലമായ_മുഖം           1
# 95  പുരുഷന്റെ ശാരീരിക ആകർഷണീയതയിൽ ആകൃഷ്ടരായ നല്ല മ...           0
# 96  നിങ്ങൾ ബുദ്ധിപരമായി സംസാരിക്കാൻ വിചാരിക്കുന്നു...           1
# 97  അവൾ വളരെ ഭംഗിയായി അഭിനയിക്കുന്നു. മഞ്ചൂരിൽ സർക...           2
#
#     predicted_label
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0
# ..              ...
# 93                1
# 94                0
# 95                1
# 96                0
# 97                0
#
# [98 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.97      0.98      0.97      1579
#   homophobic       0.78      0.82      0.80       194
#  transphobic       0.84      0.35      0.49        46
#
#     accuracy                           0.95      1819
#    macro avg       0.86      0.72      0.75      1819
# weighted avg       0.95      0.95      0.94      1819

# %% [markdown]
# #testing with tamil

# %%
o_test=pd.read_csv('/content/eng_tam_test.tsv', delimiter='\t') 
o_test = o_test.dropna()
e_test=pd.read_csv('/content/tam_3_test.tsv', delimiter='\t')
e_test=e_test[["text", "category"]] 
e_test = e_test.dropna()

# %%
test_ml = pd.concat([o_test,e_test])

# %%
test_ml['category'] = test_ml['category'].replace('Non-anti-LGBT+ content', 'ally')
test_ml['category'] = test_ml['category'].replace('ally', 0)
test_ml['category'] = test_ml['category'].replace('Homophobic', 1)
test_ml['category'] = test_ml['category'].replace('Transphobic', 2)

# %%
test_ml=test_ml[["text", "category"]]
test_ml = test_ml.rename(columns={'text': 'text', 'category': 'labels'})

# %%
test_ml['text'] = test_ml['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))

# %%
test = test_ml['text'].tolist()
labels = test_ml['labels'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/1819 [00:00<?, ?it/s]
#   0%|          | 0/114 [00:00<?, ?it/s]
#                                                   text  true_label  \
# 0                        இது முற்றிலும் உயிரியல் தான்!           0
# 1    எனது கருத்துக்கு பதிலளித்த நீங்கள் இருவரும் இத...           1
# 2    மனநோய் என்று நினைக்கிறேன். சென்று மருத்துவரை அ...           1
# 3    டைரக்டர் சார் ப்ளீஸ் கே தவம் ஆகுற மாரி படம் எட...           1
# 4    நாங்கள் ரயில்வே போலீஸ் ஓ, மன்னிக்கவும், அவர்கள...           1
# ..                                                 ...         ...
# 131  Hasanfarook Kadar  ஆண்கள் போல நடந்து கொள்ளும் ...           2
# 132  மனிதன் செய்யகூடிய சகல காரியங்களுக்கும் நியாயதீ...           1
# 133  அரவாணிய கொல்லனும் உழைக்காம பிச்ச எடுத்து திங்க...           2
# 134  நண்பா   பல்லுள்ள வாய்க்கு வேண்டிய கத்தரிக்காயை...           0
# 135  அருமை பேச்சு .இனிமையான குரல். கேள்விக்கேற்ற பத...           1
#
#      predicted_label
# 0                  1
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ..               ...
# 131                1
# 132                0
# 133                0
# 134                1
# 135                0
#
# [136 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.95      0.97      0.96      1579
#   homophobic       0.75      0.65      0.70       194
#  transphobic       0.51      0.39      0.44        46
#
#     accuracy                           0.93      1819
#    macro avg       0.74      0.67      0.70      1819
# weighted avg       0.92      0.93      0.92      1819

# %% [markdown]
# #testing with english

# %%
o_test=pd.read_csv('/content/tam_eng_test.tsv', delimiter='\t') 
o_test = o_test.dropna()
e_test=pd.read_csv('/content/eng_3_test.tsv', delimiter='\t')
e_test = e_test.rename(columns={'text                        ': 'text'})
#e_test=e_test[["text", "category"]] 
e_test = e_test.dropna()

# %%
test_ml = pd.concat([o_test,e_test])
test_ml
# Out:
#      Unnamed: 0                                               text  \
# 0           0.0        When each commanta was read and brought up.
# 1           1.0  Bro live a prosperous bouquet OK_hand OK_hand ...
# 2           2.0                             Jesus is a step sister
# 3           3.0                              Eyes are confused....
# 4           4.0  Come together Gay mean not sex it's love also ...
# ..          ...                                                ...
# 985         NaN  Looks like Karthik took advantage on Varun whe...
# 986         NaN  i am really crying pro😢😢😢😭😭😭😭😭😭               ...
# 987         NaN  They may be transgender but don't ever forgot ...
# 988         NaN  It is their own choice. I support them No doub...
# 989         NaN  Waited for a long time congrts team... such a ...
#
#                    category       ln
# 0    Non-anti-LGBT+ content  tam_eng
# 1    Non-anti-LGBT+ content  tam_eng
# 2    Non-anti-LGBT+ content  tam_eng
# 3    Non-anti-LGBT+ content  tam_eng
# 4    Non-anti-LGBT+ content  tam_eng
# ..                      ...      ...
# 985  Non-anti-LGBT+ content      NaN
# 986  Non-anti-LGBT+ content      NaN
# 987  Non-anti-LGBT+ content      NaN
# 988  Non-anti-LGBT+ content      NaN
# 989  Non-anti-LGBT+ content      NaN
#
# [1819 rows x 4 columns]

# %%
test_ml['category'] = test_ml['category'].replace('Non-anti-LGBT+ content', 'ally')
test_ml['category'] = test_ml['category'].replace('ally', 0)
test_ml['category'] = test_ml['category'].replace('Homophobic', 1)
test_ml['category'] = test_ml['category'].replace('Transphobic', 2)

# %%
test_ml=test_ml[["text", "category"]]
test_ml = test_ml.rename(columns={'text': 'text', 'category': 'labels'})

# %%
test_ml['text'] = test_ml['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))

# %%
test = test_ml['text'].tolist()
labels = test_ml['labels'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/1819 [00:00<?, ?it/s]
#   0%|          | 0/114 [00:00<?, ?it/s]
#                                                   text  true_label  \
# 0    Similarly, in all matters, the law will come a...           1
# 1    Gay ah they are not wrong...it is created by L...           0
# 2                     pranesh G you are a transgender.           2
# 3               This is very wrong. Detestable to God.           1
# 4                Many extroverts say this is unnatural           0
# ..                                                 ...         ...
# 104  gay culture does not suit the Indian culture. ...           1
# 105  First of all, i wanna know onething. Do you th...           1
# 106  madam nalini....u talking too much right....ok...           1
# 107  Friendship s friendship.dont make it as sexual...           1
# 108    She is innocent nd cute                                   0
#
#      predicted_label
# 0                  0
# 1                  1
# 2                  0
# 3                  0
# 4                  1
# ..               ...
# 104                0
# 105                0
# 106                0
# 107                0
# 108                1
#
# [109 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.96      0.98      0.97      1579
#   homophobic       0.81      0.69      0.74       194
#  transphobic       0.85      0.48      0.61        46
#
#     accuracy                           0.94      1819
#    macro avg       0.87      0.72      0.77      1819
# weighted avg       0.94      0.94      0.94      1819
