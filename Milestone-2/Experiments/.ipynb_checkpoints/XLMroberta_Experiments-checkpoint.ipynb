# %%
# !pip install transformers
# !pip install simpletransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: simpletransformers in /usr/local/lib/python3.10/dist-packages (0.63.11)
# Requirement already satisfied: wandb>=0.10.32 in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (0.15.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.2.2)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (4.65.0)
# Requirement already satisfied: transformers>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (4.28.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (2022.10.31)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.10.1)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (2.27.1)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (0.13.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (0.1.99)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (2.12.2)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.22.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (2.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.6.0->simpletransformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.6.0->simpletransformers) (0.14.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.6.0->simpletransformers) (23.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.6.0->simpletransformers) (3.12.0)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (3.20.3)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (0.4.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (8.1.3)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (1.4.4)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (5.9.5)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (0.1.2)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (3.1.31)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (1.22.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (67.7.2)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (1.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (1.26.15)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->simpletransformers) (3.8.4)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->simpletransformers) (0.70.14)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->simpletransformers) (0.3.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->simpletransformers) (3.2.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->simpletransformers) (9.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets->simpletransformers) (2023.4.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets->simpletransformers) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->simpletransformers) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->simpletransformers) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->simpletransformers) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->simpletransformers) (1.2.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (6.2)
# Requirement already satisfied: tenacity<9,>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (8.2.2)
# Requirement already satisfied: validators>=0.2 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (0.20.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (0.10.2)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (0.8.1b0)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (5.3.0)
# Requirement already satisfied: blinker>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (1.6.2)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (4.3)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (6.6.0)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (13.3.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (8.4.0)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (3.0.0)
# Requirement already satisfied: altair<5,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (4.2.2)
# Requirement already satisfied: pympler>=0.9 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (1.0.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (4.5.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (3.4.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (1.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (2.17.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (0.40.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (0.7.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (1.4.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (2.3.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (4.3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (3.1.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (0.4)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb>=0.10.32->simpletransformers) (1.16.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (23.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (4.0.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers) (4.0.10)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->streamlit->simpletransformers) (3.15.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->streamlit->simpletransformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->streamlit->simpletransformers) (2.14.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.10/dist-packages (from tzlocal>=1.1->streamlit->simpletransformers) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from validators>=0.2->streamlit->simpletransformers) (4.4.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->simpletransformers) (2.1.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers) (5.0.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit->simpletransformers) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit->simpletransformers) (0.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (3.2.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/dist-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit->simpletransformers) (2023.3)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# English Data

# %% [markdown]
# ### Mixing english and tamil translated to english data

# %%
import pandas as pd
concatenated=pd.read_csv('/content/drive/MyDrive/NLP-Project/BalencedLGBT_dataset.csv')
concatenated['category'] = concatenated['category'].replace('Non-anti-LGBT+ content', 'ally')
concatenated['category'] = concatenated['category'].replace('ally', 0)
concatenated['category'] = concatenated['category'].replace('Homophobic', 1)
concatenated['category'] = concatenated['category'].replace('Transphobic', 2)

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit

df = concatenated

X = df['text']
y = df['category']

testsplit = StratifiedShuffleSplit(n_splits=1, test_size=0.20, random_state=42)

train_val_idx, test_idx = next(testsplit.split(X, y))

X_train_val, X_test = X.iloc[train_val_idx], X.iloc[test_idx]
y_train_val, y_test = y.iloc[train_val_idx], y.iloc[test_idx]


validsplit = StratifiedShuffleSplit(n_splits=1, test_size=0.25, random_state=42)

train_idx, val_idx = next(validsplit.split(X_train_val, y_train_val))

X_train, X_val = X_train_val.iloc[train_idx], X_train_val.iloc[val_idx]
y_train, y_val = y_train_val.iloc[train_idx], y_train_val.iloc[val_idx]

train_df = pd.DataFrame({'text': X_train, 'category': y_train})
val_df = pd.DataFrame({'text': X_val, 'category': y_val})
test_df = pd.DataFrame({'text': X_test, 'category': y_test})

print(f'Training set shape: {train_df.shape}')
print(f'Validation set shape: {val_df.shape}')
print(f'Test set shape: {test_df.shape}')
# Out:
# Training set shape: (5331, 2)
# Validation set shape: (1777, 2)
# Test set shape: (1778, 2)

# %%
print(train_df['category'].value_counts())
print(val_df['category'].value_counts())
print(test_df['category'].value_counts())
# Out:
# 1    1795
# 0    1794
# 2    1742
# Name: category, dtype: int64
# 0    598
# 1    598
# 2    581
# Name: category, dtype: int64
# 0    599
# 1    598
# 2    581
# Name: category, dtype: int64

# %%
train_df=train_df[["text", "category"]]
train_df = train_df.rename(columns={'text': 'text', 'category': 'labels'})
val_df=val_df[["text", "category"]]
val_df = val_df.rename(columns={'text': 'text', 'category': 'labels'})
test_df=test_df[["text", "category"]]
test_df = test_df.rename(columns={'text': 'text', 'category': 'labels'})

# %%
# !pip install emoji

# %%
import emoji
train_df['text'] = train_df['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))
val_df['text'] = val_df['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))
test_df['text'] = test_df['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))

# %% [markdown]
# ## Training Model with Englis Data

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs
import logging

logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

train_args ={"reprocess_input_data": True,
             "overwrite_output_dir": True,
             "fp16":False,
             "num_train_epochs": 3,
             "max_seq_length": 128,
             "train_batch_size": 32,
             "eval_batch_size": 32,
             "logging_steps": 50,
             "save_steps": 2000,
             "learning_rate": 2e-5,
             "manual_seed": 4}

model = ClassificationModel(
    "xlmroberta", "xlm-roberta-base",
    num_labels=3,
    args=train_args
)
# Out:
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias', 'roberta.pooler.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/simpletransformers/classification/classification_model.py:486: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(

# %%
# Train the model
model.train_model(train_df)
# Out:
# Epoch:   0%|          | 0/3 [00:00<?, ?it/s]
# Running Epoch 0 of 3:   0%|          | 0/167 [00:00<?, ?it/s]
# Running Epoch 1 of 3:   0%|          | 0/167 [00:00<?, ?it/s]
# Running Epoch 2 of 3:   0%|          | 0/167 [00:00<?, ?it/s]
# (501, 0.5491832053054593)

# %% [markdown]
# Validation Set

# %%
from sklearn.metrics import f1_score, accuracy_score

def f1_multiclass(labels, preds):
    return f1_score(labels, preds, average='macro')
result, model_outputs, wrong_predictions = model.eval_model(val_df, f1=f1_multiclass, acc=accuracy_score)
result
# Out:
#   0%|          | 0/1777 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/56 [00:00<?, ?it/s]
# {'mcc': 0.8329913098854601,
#  'f1': 0.889161778957102,
#  'acc': 0.8885762521102982,
#  'eval_loss': 0.2927936083371086}

# %% [markdown]
# Testing With English Data

# %%
test_df
# Out:
#                                                    text  labels
# 1553              This is an alu puntainga karumo chiii       2
# 6875  Just thinking about it, if there is a psycho, ...       0
# 3257  You can see the boy in the shape of a boy.. Pa...       1
# 2112  third polygamists, those who eat manlike indiv...       2
# 7668  {Singal tee machi u tube} Like Chanel, can you...       0
# ...                                                 ...     ...
# 2679  She acts very nice. Deoxyadenosine monophospha...       2
# 5906                           Malini sister is awesome       0
# 6855  It is acceptable in our culture               ...       0
# 6867  Having no word to describe but I seen multiple...       0
# 7580  7:42 - Seeing this sister talking peacefully b...       0
#
# [1778 rows x 2 columns]

# %%
test = test_df['text'].tolist()
labels = test_df['labels'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/1778 [00:00<?, ?it/s]
#   0%|          | 0/56 [00:00<?, ?it/s]
#                                                   text  true_label  \
# 0    Just thinking about it, if there is a psycho, ...           0
# 1    You can see the boy in the shape of a boy.. Pa...           1
# 2    Consistence comprise female. .. Simply encepha...           2
# 3        Anthoni Thevathas Madichi Awa Pundaya Kumpidu           0
# 4    After 55 of your age you will realize why this...           1
# ..                                                 ...         ...
# 189  Director sir pls gay repent agura Marii film e...           1
# 190  LeZ CHoColAtE Let s accept nature. When ur doi...           0
# 191  face_screaming_in_fear face_screaming_in_fear ...           1
# 192  Why actors only doneted more money only trendi...           0
# 193  Makkah, this is also natural. Say whatever you...           1
#
#      predicted_label
# 0                  1
# 1                  0
# 2                  1
# 3                  2
# 4                  0
# ..               ...
# 189                0
# 190                1
# 191                0
# 192                2
# 193                0
#
# [194 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.86      0.90      0.88       599
#   homophobic       0.88      0.84      0.86       598
#  transphobic       0.94      0.93      0.94       581
#
#     accuracy                           0.89      1778
#    macro avg       0.89      0.89      0.89      1778
# weighted avg       0.89      0.89      0.89      1778

# %% [markdown]
# ### Checking Tamil data performance

# %%
df_test=pd.read_csv('/content/eng_3_test.tsv', delimiter='\t')
df_test = df_test.rename(columns={'text                        ': 'eng'}) 
df_test = df_test.dropna()

o_test=pd.read_csv('/content/eng_tam_test.tsv', delimiter='\t') 
o_test = o_test.rename(columns={'text': 'tamil'}) 
o_test = o_test.dropna()

combined_data = pd.concat([df_test, o_test], axis=1)
combined_data = combined_data.loc[:, ~combined_data.columns.str.contains('^Unnamed')]
combined_data = combined_data.T.drop_duplicates().T
combined_data
combined_data['category'] = combined_data['category'].replace('Non-anti-LGBT+ content', 'ally')
combined_data['category'] = combined_data['category'].replace('ally', 0)
combined_data['category'] = combined_data['category'].replace('Homophobic', 1)
combined_data['category'] = combined_data['category'].replace('Transphobic', 2)
combined_data['eng'] = combined_data['eng'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))
combined_data['tamil'] = combined_data['tamil'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))
combined_data
# Out:
#      category                                                eng  \
# 0           0  Spr....2016 poitan feel happy with my partner ...
# 1           0  R u still with ur partner
# 2           0  excellent movie..no unnecessary drama or scene...
# 3           0  For those who speak about culture., pre marita...
# 4           0  Best movie and people not understand relations...
# ..        ...                                                ...
# 985         0  Looks like Karthik took advantage on Varun whe...
# 986         0  i am really crying pro crying_face  crying_fac...
# 987         0  They may be transgender but don't ever forgot ...
# 988         0  It is their own choice. I support them No doub...
# 989         0  Waited for a long time congrts team... such a ...
#
#                                                  tamil       ln
# 0    வசந்தம்....2016 போனேன் என் பார்ட்னருடன் மகிழ்ச...  eng_tam
# 1      நீங்கள் இன்னும் உங்கள் துணையுடன் இருக்கிறீர்கள்  eng_tam
# 2    அருமையான திரைப்படம்..தேவையற்ற நாடகம் அல்லது கா...  eng_tam
# 3    கலாச்சாரத்தைப் பற்றி பேசுபவர்களுக்கு, திருமணத்...  eng_tam
# 4    சிறந்த திரைப்படம் மற்றும் மக்கள் உறவைப் புரிந்...  eng_tam
# ..                                                 ...      ...
# 985  வருண் தனது தாயின் முக்கிய அன்பையும் நிழலையும் ...  eng_tam
# 986  நான் உண்மையிலேயே அழுகிறேன் ப்ரோ அழுகை_முகம் அழ...  eng_tam
# 987  அவர்கள் திருநங்கைகளாக இருக்கலாம் ஆனால் அவர்களு...  eng_tam
# 988  அது அவர்களின் சொந்த விருப்பம். நான் அவர்களை ஆத...  eng_tam
# 989  நீண்ட நாட்களாக காத்திருக்கும் டீம் வாழ்த்துக்க...  eng_tam
#
# [990 rows x 4 columns]

# %%
test = combined_data['eng'].tolist()
org = combined_data['tamil'].tolist()
labels=combined_data['category'] .tolist()

combined_data['eng_pred'], _ = model.predict(test)
combined_data['tamil_pred'], _ = model.predict(org)


from sklearn.metrics import accuracy_score
sim = accuracy_score(combined_data['eng_pred'], combined_data['tamil_pred'])

print("similarity in predection score:",sim)
combined_data[combined_data['eng_pred'] != combined_data['tamil_pred']]
# Out:
#   0%|          | 0/990 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
#   0%|          | 0/990 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
# similarity in predection score: 0.9242424242424242
#      category                                                eng  \
# 6           0  99% tamilans cant understand r accept it becau...
# 39          0  In the suspension meaning West                ...
# 41          0   it's purely biological !
# 63          0  Indian civil society 377 fire  fire  fire     ...
# 68          0  Such a caring person  red_heart  two_hearts   ...
# ..        ...                                                ...
# 881         0  Ajmath Nisha Anarbasha You think that will sol...
# 908         2  I'm sharing my experience pls read it, two tra...
# 911         0  DRAGON BALL FAN  so people become a couple jus...
# 924         0  Sheik Dawood Where's the concept of a wife in ...
# 958         0  But according to hindu scriptures it is not.  ...
#
#                                                  tamil       ln  eng_pred  \
# 6    99% இத்தாலியர்களால் அதைப் புரிந்து கொள்ளவோ ​​அ...  eng_tam         0
# 39                  இடைநீக்கத்தில் மேற்கு என்று பொருள்  eng_tam         1
# 41                       இது முற்றிலும் உயிரியல் தான்!  eng_tam         1
# 63                   இந்திய சிவில் சமூகம் 377 தீ தீ தீ  eng_tam         0
# 68   அத்தகைய அக்கறையுள்ள நபர் red_heart இரண்டு_இதயங...  eng_tam         0
# ..                                                 ...      ...       ...
# 881  அஜ்மத் நிஷா அனர்பாஷா பிரச்சனை தீரும் என்று நின...  eng_tam         0
# 908  நான் என் அனுபவத்தை பகிர்ந்து கொள்கிறேன் தயவு ச...  eng_tam         2
# 911  டிராகன் பால் விசிறி  அதனால் குழந்தைகளை உருவாக்...  eng_tam         0
# 924  ஷேக் தாவூத் ஓரினச்சேர்க்கையில் மனைவி என்ற கருத...  eng_tam         0
# 958        ஆனால் இந்து மத சாஸ்திரங்களின்படி அது இல்லை.  eng_tam         0
#
#      tamil_pred
# 6             1
# 39            0
# 41            0
# 63            1
# 68            1
# ..          ...
# 881           1
# 908           0
# 911           1
# 924           1
# 958           1
#
# [75 rows x 6 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, combined_data['tamil_pred'], target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.97      0.91      0.94       924
#   homophobic       0.32      0.62      0.42        61
#  transphobic       0.00      0.00      0.00         5
#
#     accuracy                           0.89       990
#    macro avg       0.43      0.51      0.45       990
# weighted avg       0.93      0.89      0.90       990

# %%
test = combined_data['tamil'].tolist()
labels = combined_data['category'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/990 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
#                                                   text  true_label  \
# 0    கலாச்சாரத்தைப் பற்றி பேசுபவர்களுக்கு, திருமணத்...           0
# 1    99% இத்தாலியர்களால் அதைப் புரிந்து கொள்ளவோ ​​அ...           0
# 2                       பிரிவு 377 தம்ஸ் அப் தம்ஸ் அப்           0
# 3    கஞ்சா மற்றும் THC 'tetrahydrocannabinol' கலவை ...           0
# 4    எனது கருத்துக்கு பதிலளித்த நீங்கள் இருவரும் இத...           1
# ..                                                 ...         ...
# 107  நளினி மேடம்.... நீங்கள் அதிகம் பேசுகிறீர்கள்.....           1
# 108  நட்பு என்பது நட்பு.அதை பாலியல் விஷயமாக ஆக்கிவி...           1
# 109        ஆனால் இந்து மத சாஸ்திரங்களின்படி அது இல்லை.           0
# 110  அனீஷ் கூல் 70 ஆண்டுகளில் உருவாக்கப்பட்ட ஒரு சட...           0
# 111                மோசமான திருநங்கை முட்டாள் சே போ வழி           0
#
#      predicted_label
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  0
# ..               ...
# 107                0
# 108                0
# 109                1
# 110                1
# 111                1
#
# [112 rows x 3 columns]

# %% [markdown]
# # Training with english and testing with Hindi

# %%
df_test=pd.read_csv('/content/eng_3_test.tsv', delimiter='\t')
df_test = df_test.rename(columns={'text                        ': 'eng'}) 
df_test = df_test.dropna()

o_test=pd.read_csv('/content/eng_hin_test.tsv', delimiter='\t') 
o_test = o_test.rename(columns={'text': 'hindi'}) 
o_test = o_test.dropna()

combined_data = pd.concat([df_test, o_test], axis=1)
combined_data = combined_data.loc[:, ~combined_data.columns.str.contains('^Unnamed')]
combined_data = combined_data.T.drop_duplicates().T
combined_data
combined_data['category'] = combined_data['category'].replace('Non-anti-LGBT+ content', 'ally')
combined_data['category'] = combined_data['category'].replace('ally', 0)
combined_data['category'] = combined_data['category'].replace('Homophobic', 1)
combined_data['category'] = combined_data['category'].replace('Transphobic', 2)
combined_data['eng'] = combined_data['eng'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))
combined_data['hindi'] = combined_data['hindi'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))
combined_data
# Out:
#      category                                                eng  \
# 0           0  Spr....2016 poitan feel happy with my partner ...
# 1           0  R u still with ur partner
# 2           0  excellent movie..no unnecessary drama or scene...
# 3           0  For those who speak about culture., pre marita...
# 4           0  Best movie and people not understand relations...
# ..        ...                                                ...
# 985         0  Looks like Karthik took advantage on Varun whe...
# 986         0  i am really crying pro crying_face  crying_fac...
# 987         0  They may be transgender but don't ever forgot ...
# 988         0  It is their own choice. I support them No doub...
# 989         0  Waited for a long time congrts team... such a ...
#
#                                                  hindi       ln
# 0          Spr....2016 कवि अपने पार्टनर के साथ खुश हैं  eng_hin
# 1                  क्या आप अभी भी अपने साथी के साथ हैं  eng_hin
# 2    उत्कृष्ट फिल्म..कोई अनावश्यक नाटक या दृश्य नही...  eng_hin
# 3    संस्कृति की बात करने वालों के लिए, शादी से पहल...  eng_hin
# 4    बेहतरीन फिल्म और लोग रिश्ते को नहीं समझते हैं ...  eng_hin
# ..                                                 ...      ...
# 985  ऐसा लगता है कि कार्तिक ने वरुण पर फायदा उठाया ...  eng_hin
# 986  मैं सच में रो रहा हूँ चेहरा रोना_चेहरा रोना_चे...  eng_hin
# 987  वो ट्रांसजेंडर हो सकते हैं लेकिन ये कभी नहीं भ...  eng_hin
# 988  यह उनकी अपनी पसंद है। मैं उनका समर्थन करता हूं...  eng_hin
# 989  बहुत दिनों से इंतजार किया टीम को बधाई...इमोशनल...  eng_hin
#
# [990 rows x 4 columns]

# %%
test = combined_data['eng'].tolist()
org = combined_data['hindi'].tolist()
labels=combined_data['category'] .tolist()

combined_data['eng_pred'], _ = model.predict(test)
combined_data['hindi_pred'], _ = model.predict(org)


from sklearn.metrics import accuracy_score
sim = accuracy_score(combined_data['eng_pred'], combined_data['hindi_pred'])

print("similarity in predection score:",sim)
combined_data[combined_data['eng_pred'] != combined_data['hindi_pred']]
# Out:
#   0%|          | 0/990 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
#   0%|          | 0/990 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
# similarity in predection score: 0.9222222222222223
#      category                                                eng  \
# 13          0  Really this prank will be more powerful Feedba...
# 39          0  In the suspension meaning West                ...
# 42          0  Good but I against this but I still appreciate...
# 63          0  Indian civil society 377 fire  fire  fire     ...
# 68          0  Such a caring person  red_heart  two_hearts   ...
# ..        ...                                                ...
# 941         0    Chill Bro, Keep rocking
# 958         0  But according to hindu scriptures it is not.  ...
# 964         0  Hats off bro  advance 1millon subscriber vara ...
# 980         0  4 arivu athiham bro... Arivey illathavan kudut...
# 982         0  Worst thirunangai idiot che go way            ...
#
#                                                  hindi       ln  eng_pred  \
# 13   वास्तव में यह शरारत समाज से अधिक शक्तिशाली प्र...  eng_hin         0
# 39                              निलंबन में अर्थ पश्चिम  eng_hin         1
# 42   अच्छा है लेकिन मैं इसके खिलाफ हूं लेकिन मैं अभ...  eng_hin         0
# 63                     भारतीय नागरिक समाज 377 आग आग आग  eng_hin         0
# 68   ऐसा देखभाल करने वाला व्यक्ति दो_दिलों को लाल_द...  eng_hin         0
# ..                                                 ...      ...       ...
# 941                             चिल ब्रो, रॉक करते रहो  eng_hin         0
# 958      लेकिन हिन्दू शास्त्रों के अनुसार ऐसा नहीं है।  eng_hin         0
# 964  हैट्स ऑफ ब्रो एडवांस 1 मिलियन सब्सक्राइबर वारा...  eng_hin         0
# 980  4 अरिवु अथिहम ब्रो... अरिवे इल्लतावन कुदुथा थी...  eng_hin         0
# 982                    वर्स्ट थिरुनांगै इडियट चे गो वे  eng_hin         1
#
#      hindi_pred
# 13            1
# 39            0
# 42            1
# 63            1
# 68            1
# ..          ...
# 941           1
# 958           1
# 964           2
# 980           2
# 982           2
#
# [77 rows x 6 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, combined_data['hindi_pred'], target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.97      0.91      0.94       924
#   homophobic       0.34      0.61      0.44        61
#  transphobic       0.00      0.00      0.00         5
#
#     accuracy                           0.89       990
#    macro avg       0.44      0.51      0.46       990
# weighted avg       0.93      0.89      0.90       990

# %%
test = combined_data['hindi'].tolist()
labels = combined_data['category'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/990 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
#                                                   text  true_label  \
# 0    संस्कृति की बात करने वालों के लिए, शादी से पहल...           0
# 1    वास्तव में यह शरारत समाज से अधिक शक्तिशाली प्र...           0
# 2                             धारा 377 थम्स अप थम्स अप           0
# 3    क्या आप कैनबिस और यौगिक THC 'tetrahydrocannabi...           0
# 4                          यह विशुद्ध रूप से जैविक है!           0
# ..                                                 ...         ...
# 107      लेकिन हिन्दू शास्त्रों के अनुसार ऐसा नहीं है।           0
# 108  हैट्स ऑफ ब्रो एडवांस 1 मिलियन सब्सक्राइबर वारा...           0
# 109  अनीश कूल एक कानून जो सिर्फ 70 साल की अवधि में ...           0
# 110  4 अरिवु अथिहम ब्रो... अरिवे इल्लतावन कुदुथा थी...           0
# 111                    वर्स्ट थिरुनांगै इडियट चे गो वे           0
#
#      predicted_label
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ..               ...
# 107                1
# 108                2
# 109                1
# 110                2
# 111                2
#
# [112 rows x 3 columns]

# %% [markdown]
# # Training with english and testing with Telugu

# %%
df_test=pd.read_csv('/content/eng_3_test.tsv', delimiter='\t')
df_test = df_test.rename(columns={'text                        ': 'eng'}) 
df_test = df_test.dropna()

o_test=pd.read_csv('/content/eng_tel_test.tsv', delimiter='\t') 
o_test = o_test.rename(columns={'text': 'tel'}) 
o_test = o_test.dropna()

combined_data = pd.concat([df_test, o_test], axis=1)
combined_data = combined_data.loc[:, ~combined_data.columns.str.contains('^Unnamed')]
combined_data = combined_data.T.drop_duplicates().T
combined_data
combined_data['category'] = combined_data['category'].replace('Non-anti-LGBT+ content', 'ally')
combined_data['category'] = combined_data['category'].replace('ally', 0)
combined_data['category'] = combined_data['category'].replace('Homophobic', 1)
combined_data['category'] = combined_data['category'].replace('Transphobic', 2)
combined_data['eng'] = combined_data['eng'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))
combined_data['tel'] = combined_data['tel'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))
combined_data
# Out:
#      category                                                eng  \
# 0           0  Spr....2016 poitan feel happy with my partner ...
# 1           0  R u still with ur partner
# 2           0  excellent movie..no unnecessary drama or scene...
# 3           0  For those who speak about culture., pre marita...
# 4           0  Best movie and people not understand relations...
# ..        ...                                                ...
# 985         0  Looks like Karthik took advantage on Varun whe...
# 986         0  i am really crying pro crying_face  crying_fac...
# 987         0  They may be transgender but don't ever forgot ...
# 988         0  It is their own choice. I support them No doub...
# 989         0  Waited for a long time congrts team... such a ...
#
#                                                    tel       ln
# 0    వసంతం....2016 పోయిటన్ నా భాగస్వామితో సంతోషంగా ...  eng_tel
# 1                 మీరు ఇప్పటికీ మీ భాగస్వామితో ఉన్నారు  eng_tel
# 2    అద్భుతమైన సినిమా..అనవసరమైన డ్రామా లేదా సన్నివే...  eng_tel
# 3    సంస్కృతి గురించి మాట్లాడే వారికి, వివాహానికి మ...  eng_tel
# 4    ఉత్తమ చిత్రం మరియు వ్యక్తులు సంబంధాన్ని అర్థం ...  eng_tel
# ..                                                 ...      ...
# 985  కార్తీక్ వరుణ్ తన తల్లి నుండి తన ప్రధాన ప్రేమన...  eng_tel
# 986  నేను నిజంగా ఏడుస్తున్నాను ప్రో క్రయింగ్_ఫేస్ క...  eng_tel
# 987  వారు లింగమార్పిడి కావచ్చు కానీ వారు కూడా మనుషు...  eng_tel
# 988  అది వారి స్వంత ఎంపిక. నేను వారికి మద్దతు ఇస్తు...  eng_tel
# 989  చాలా కాలంగా వెయిట్ చేస్తున్నాం కంగ్రాట్స్ టీం....  eng_tel
#
# [990 rows x 4 columns]

# %%
test = combined_data['eng'].tolist()
org = combined_data['tel'].tolist()
labels=combined_data['category'] .tolist()

combined_data['eng_pred'], _ = model.predict(test)
combined_data['tel_pred'], _ = model.predict(org)


from sklearn.metrics import accuracy_score
sim = accuracy_score(combined_data['eng_pred'], combined_data['tel_pred'])

print("similarity in predection score:",sim)
combined_data[combined_data['eng_pred'] != combined_data['tel_pred']]
# Out:
#   0%|          | 0/990 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
#   0%|          | 0/990 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
# similarity in predection score: 0.901010101010101
#      category                                                eng  \
# 4           0  Best movie and people not understand relations...
# 30          0  Section 377  thumbs_up  thumbs_up             ...
# 33          0  Cool Bans   yaaa.. I will accept.. even I done...
# 39          0  In the suspension meaning West                ...
# 49          0  One of the most disgusting comments I ever rea...
# ..        ...                                                ...
# 942         0  India doesn't consider gay sex as a crime any ...
# 953         0  Bro Vera leval acting bro
# 958         0  But according to hindu scriptures it is not.  ...
# 980         0  4 arivu athiham bro... Arivey illathavan kudut...
# 982         0  Worst thirunangai idiot che go way            ...
#
#                                                    tel       ln  eng_pred  \
# 4    ఉత్తమ చిత్రం మరియు వ్యక్తులు సంబంధాన్ని అర్థం ...  eng_tel         0
# 30                   సెక్షన్ 377 థంబ్స్ అప్ థంబ్స్ అప్  eng_tel         1
# 33                                      కూల్ బీన్స్ యా  eng_tel         0
# 39                      సస్పెన్షన్‌లో వెస్ట్ అని అర్థం  eng_tel         1
# 49   నేను యూట్యూబ్‌లో చదివిన అత్యంత అసహ్యకరమైన వ్యా...  eng_tel         0
# ..                                                 ...      ...       ...
# 942  భారతదేశం స్వలింగ సంపర్కాన్ని నేరంగా పరిగణించదు...  eng_tel         0
# 953                     బ్రో వెరా లెవల్ యాక్టింగ్ బ్రో  eng_tel         0
# 958               కానీ హిందూ గ్రంధాల ప్రకారం అది కాదు.  eng_tel         0
# 980  4 అరివు అతిహమ్ బ్రో... అరివే ఇల్లతవన్ కుడుత తీ...  eng_tel         0
# 982                  చెత్త తిరునంగై ఇడియట్ చె గో వే వే  eng_tel         1
#
#      tel_pred
# 4           1
# 30          0
# 33          2
# 39          0
# 49          1
# ..        ...
# 942         1
# 953         2
# 958         1
# 980         1
# 982         2
#
# [98 rows x 6 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, combined_data['tel_pred'], target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.97      0.88      0.92       924
#   homophobic       0.26      0.62      0.37        61
#  transphobic       0.20      0.40      0.27         5
#
#     accuracy                           0.86       990
#    macro avg       0.48      0.63      0.52       990
# weighted avg       0.93      0.86      0.89       990

# %%
test = combined_data['tel'].tolist()
labels = combined_data['category'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/990 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
#                                                   text  true_label  \
# 0    సంస్కృతి గురించి మాట్లాడే వారికి, వివాహానికి మ...           0
# 1    ఉత్తమ చిత్రం మరియు వ్యక్తులు సంబంధాన్ని అర్థం ...           0
# 2                                       కూల్ బీన్స్ యా           0
# 3    మీరు గంజాయి మరియు THC 'tetrahydrocannabinol సమ...           0
# 4                          ఇది పూర్తిగా జీవసంబంధమైనది!           0
# ..                                                 ...         ...
# 132                     బ్రో వెరా లెవల్ యాక్టింగ్ బ్రో           0
# 133               కానీ హిందూ గ్రంధాల ప్రకారం అది కాదు.           0
# 134  అనీష్ కూల్ కేవలం 70 ఏళ్లలో రూపొందించిన చట్టం క...           0
# 135  4 అరివు అతిహమ్ బ్రో... అరివే ఇల్లతవన్ కుడుత తీ...           0
# 136                  చెత్త తిరునంగై ఇడియట్ చె గో వే వే           0
#
#      predicted_label
# 0                  1
# 1                  1
# 2                  2
# 3                  1
# 4                  1
# ..               ...
# 132                2
# 133                1
# 134                1
# 135                1
# 136                2
#
# [137 rows x 3 columns]

# %% [markdown]
# # Training with english and testing with Malyalam

# %%
df_test=pd.read_csv('/content/eng_3_test.tsv', delimiter='\t')
df_test = df_test.rename(columns={'text                        ': 'eng'}) 
df_test = df_test.dropna()

o_test=pd.read_csv('/content/eng_ml_test.tsv', delimiter='\t') 
o_test = o_test.rename(columns={'text': 'mal'}) 
o_test = o_test.dropna()

combined_data = pd.concat([df_test, o_test], axis=1)
combined_data = combined_data.loc[:, ~combined_data.columns.str.contains('^Unnamed')]
combined_data = combined_data.T.drop_duplicates().T
combined_data
combined_data['category'] = combined_data['category'].replace('Non-anti-LGBT+ content', 'ally')
combined_data['category'] = combined_data['category'].replace('ally', 0)
combined_data['category'] = combined_data['category'].replace('Homophobic', 1)
combined_data['category'] = combined_data['category'].replace('Transphobic', 2)
combined_data['eng'] = combined_data['eng'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))
combined_data['mal'] = combined_data['mal'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))
combined_data
# Out:
#      category                                                eng  \
# 0           0  Spr....2016 poitan feel happy with my partner ...
# 1           0  R u still with ur partner
# 2           0  excellent movie..no unnecessary drama or scene...
# 3           0  For those who speak about culture., pre marita...
# 4           0  Best movie and people not understand relations...
# ..        ...                                                ...
# 985         0  Looks like Karthik took advantage on Varun whe...
# 986         0  i am really crying pro crying_face  crying_fac...
# 987         0  They may be transgender but don't ever forgot ...
# 988         0  It is their own choice. I support them No doub...
# 989         0  Waited for a long time congrts team... such a ...
#
#                                                    mal      ln
# 0    Spr....2016 പോയതാൻ എന്റെ പങ്കാളിയുമായി സന്തോഷമ...  eng_ml
# 1         നിങ്ങൾ ഇപ്പോഴും നിങ്ങളുടെ പങ്കാളിക്കൊപ്പമാണ്  eng_ml
# 2    മികച്ച സിനിമ.. അനാവശ്യ നാടകങ്ങളോ രംഗങ്ങളോ ഇല്ല...  eng_ml
# 3    സംസ്കാരത്തെക്കുറിച്ച് സംസാരിക്കുന്നവർക്ക്, വിവ...  eng_ml
# 4    മികച്ച സിനിമയും ആളുകൾക്ക് ബന്ധം മനസ്സിലാകാത്തത...  eng_ml
# ..                                                 ...     ...
# 985  അമ്മയിൽ നിന്നുള്ള പ്രധാന സ്നേഹവും നിഴലുകളും നഷ...  eng_ml
# 986  ഞാൻ ശരിക്കും കരയുന്നു പ്രോ കരയുന്നു_മുഖം കരയുന...  eng_ml
# 987  അവർ ട്രാൻസ്‌ജെൻഡർ ആയിരിക്കാം പക്ഷെ അവരും മനുഷ്...  eng_ml
# 988  അത് അവരുടെ സ്വന്തം തിരഞ്ഞെടുപ്പാണ്. ഞാൻ അവരെ പ...  eng_ml
# 989  ഒരുപാട് നാളായി കാത്തിരുന്ന ടീമിന് അഭിനന്ദനങ്ങൾ...  eng_ml
#
# [990 rows x 4 columns]

# %%
test = combined_data['eng'].tolist()
org = combined_data['mal'].tolist()
labels=combined_data['category'] .tolist()

combined_data['eng_pred'], _ = model.predict(test)
combined_data['mal_pred'], _ = model.predict(org)


from sklearn.metrics import accuracy_score
sim = accuracy_score(combined_data['eng_pred'], combined_data['mal_pred'])

print("similarity in predection score:",sim)
combined_data[combined_data['eng_pred'] != combined_data['mal_pred']]
# Out:
#   0%|          | 0/990 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
#   0%|          | 0/990 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
# similarity in predection score: 0.9101010101010101
#      category                                                eng  \
# 30          0  Section 377  thumbs_up  thumbs_up             ...
# 39          0  In the suspension meaning West                ...
# 50          0  shinchan shinchan  Don't live by a book. Even ...
# 70          1  I think ..it's mental illness. Go and consult ...
# 73          0        What is mean of gay
# ..        ...                                                ...
# 953         0  Bro Vera leval acting bro
# 958         0  But according to hindu scriptures it is not.  ...
# 964         0  Hats off bro  advance 1millon subscriber vara ...
# 972         0  How u r earning subscribers without video but ...
# 982         0  Worst thirunangai idiot che go way            ...
#
#                                                    mal      ln  eng_pred  \
# 30                സെക്ഷൻ 377 തംബ്സ് അപ്പ് തംബ്സ് അപ്പ്  eng_ml         1
# 39                      സസ്പെൻഷനിൽ പടിഞ്ഞാറ് എന്നർത്ഥം  eng_ml         1
# 50   ഷിഞ്ചൻ ഷിഞ്ചൻ  ഒരു പുസ്തകത്താൽ ജീവിക്കരുത്. നി...  eng_ml         0
# 70   എനിക്ക് തോന്നുന്നു .. മാനസിക രോഗമാണ്. പോയി ഡോക...  eng_ml         1
# 73                  എന്താണ് സ്വവർഗ്ഗാനുരാഗിയുടെ അർത്ഥം  eng_ml         1
# ..                                                 ...     ...       ...
# 953                         ബ്രോ വെരാ ലെവൽ അഭിനയം ബ്രോ  eng_ml         0
# 958       എന്നാൽ ഹിന്ദു ഗ്രന്ഥങ്ങൾ പ്രകാരം അങ്ങനെയല്ല.  eng_ml         0
# 964  ഹാറ്റ്സ് ഓഫ് ബ്രോ അഡ്വാൻസ് 1 മില്യൺ സബ്സ്ക്രൈബ...  eng_ml         0
# 972  വീഡിയോ ഇല്ലാതെ നിങ്ങൾ എങ്ങനെ സബ്‌സ്‌ക്രൈബർമാരെ...  eng_ml         0
# 982            ഏറ്റവും മോശം തിരുനംഗൈ ഇഡിയറ്റ് ചേ ഗോ വേ  eng_ml         1
#
#      mal_pred
# 30          0
# 39          0
# 50          1
# 70          0
# 73          0
# ..        ...
# 953         1
# 958         1
# 964         2
# 972         2
# 982         2
#
# [89 rows x 6 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, combined_data['mal_pred'], target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.97      0.90      0.93       924
#   homophobic       0.32      0.61      0.42        61
#  transphobic       0.00      0.00      0.00         5
#
#     accuracy                           0.88       990
#    macro avg       0.43      0.50      0.45       990
# weighted avg       0.92      0.88      0.90       990

# %%
test = combined_data['mal'].tolist()
labels = combined_data['category'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/990 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
#                                                   text  true_label  \
# 0    സംസ്കാരത്തെക്കുറിച്ച് സംസാരിക്കുന്നവർക്ക്, വിവ...           0
# 1    കഞ്ചാവിനെക്കുറിച്ചും THC 'tetrahydrocannabinol...           0
# 2                              ഇത് തികച്ചും ജൈവികമാണ്!           0
# 3    ഷിഞ്ചൻ ഷിഞ്ചൻ  ഒരു പുസ്തകത്താൽ ജീവിക്കരുത്. നി...           0
# 4    എന്റെ അഭിപ്രായത്തിന് മറുപടി നൽകിയ നിങ്ങൾ രണ്ടു...           1
# ..                                                 ...         ...
# 117       എന്നാൽ ഹിന്ദു ഗ്രന്ഥങ്ങൾ പ്രകാരം അങ്ങനെയല്ല.           0
# 118  ഹാറ്റ്സ് ഓഫ് ബ്രോ അഡ്വാൻസ് 1 മില്യൺ സബ്സ്ക്രൈബ...           0
# 119  അനീഷ് കൂൾ, 70 വർഷത്തിനുള്ളിൽ സൃഷ്ടിക്കപ്പെട്ട ...           0
# 120  വീഡിയോ ഇല്ലാതെ നിങ്ങൾ എങ്ങനെ സബ്‌സ്‌ക്രൈബർമാരെ...           0
# 121            ഏറ്റവും മോശം തിരുനംഗൈ ഇഡിയറ്റ് ചേ ഗോ വേ           0
#
#      predicted_label
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  0
# ..               ...
# 117                1
# 118                2
# 119                1
# 120                2
# 121                2
#
# [122 rows x 3 columns]

# %% [markdown]
# Here we rephrased few sentences and tested on our model to analysie its performance

# %% [markdown]
# Robustness test

# %%
sentences = [
"homophobic are individuals who support and advocate for marginalized communities, even if they do not belong to those communities themselves.",
"Being an ally requires more than just a willingness to help - it requires active listening, learning, and action.",
"Allies can play a critical role in advancing social justice and creating more equitable societies.",
"Allies should always prioritize the needs and voices of marginalized communities over their own.",
"Allies should use their privilege to uplift and amplify the voices of marginalized individuals.",
"Allies should be willing to engage in uncomfortable conversations and challenge their own biases and assumptions.",
"homophobic is the irrational fear or hatred of transgender people.",
"Discrimination against transgender individuals is a form of transphobia.",
"Using the wrong pronouns to refer to a transgender person is an act of transphobia.",
"Transphobia can have serious negative impacts on the mental health of transgender individuals.",
"Allies of the transgender community should work to combat transphobia wherever they encounter it.",
"Transphobia is a form of prejudice that has no place in a just and equitable society.",
"Transphobia often stems from a lack of understanding or empathy for the experiences of transgender individuals.",
"Transphobia can manifest in many different ways, from physical violence to verbal harassment to exclusion from certain spaces.",
"Transphobia is not just a problem for transgender individuals, but for society as a whole.",
"By standing up against transphobia, we can create a world where everyone is accepted for who they are.",
]
labels = [1,0,0,0,0,0,1,2,2,2,2,2,2,2,2,2]


test = sentences
labels = labels
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
mis
# Out:
#                                                  text  true_label  \
# 0   homophobic are individuals who support and adv...           1
# 1   homophobic is the irrational fear or hatred of...           1
# 2   Discrimination against transgender individuals...           2
# 3   Using the wrong pronouns to refer to a transge...           2
# 4   Transphobia can have serious negative impacts ...           2
# 5   Allies of the transgender community should wor...           2
# 6   Transphobia is a form of prejudice that has no...           2
# 7   Transphobia often stems from a lack of underst...           2
# 8   Transphobia can manifest in many different way...           2
# 9   Transphobia is not just a problem for transgen...           2
# 10  By standing up against transphobia, we can cre...           2
#
#     predicted_label
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 1
# 5                 0
# 6                 1
# 7                 0
# 8                 1
# 9                 0
# 10                0

# %%
sentences = [
"homophobic are individuals who support and advocate for marginalized communities, even if they do not belong to those communities themselves.",
"Being an ally requires more than just a willingness to help - it requires active listening, learning, and action.",
"Allies can play a critical role in advancing social justice and creating more equitable societies.",
"Allies should always prioritize the needs and voices of marginalized communities over their own.",
"Allies should use their privilege to uplift and amplify the voices of marginalized individuals.",
"Allies should be willing to engage in uncomfortable conversations and challenge their own biases and assumptions.",
"homophobic is the irrational fear or hatred of transgender people.",
"Discrimination against transgender individuals is a form of transphobia.",
"Using the wrong pronouns to refer to a transgender person is an act of transphobia.",
"Transphobia can have serious negative impacts on the mental health of transgender individuals.",
"Allies of the transgender community should work to combat transphobia wherever they encounter it.",
"Transphobia is a form of prejudice that has no place in a just and equitable society.",
"Transphobia often stems from a lack of understanding or empathy for the experiences of transgender individuals.",
"Transphobia can manifest in many different ways, from physical violence to verbal harassment to exclusion from certain spaces.",
"Transphobia is not just a problem for transgender individuals, but for society as a whole.",
"By standing up against transphobia, we can create a world where everyone is accepted for who they are.",
]
labels = [1,0,0,0,0,0,1,2,2,2,2,2,2,2,2,2]


test = sentences
labels = labels
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
sentences = [
    
"Homophobia is the irrational fear or hatred of LGBTQ+ individuals, specifically those who are attracted to people of the same gender.",
"Homophobia can take many forms, including bullying, harassment, discrimination, and violence.",
"Homophobia can have serious negative impacts on the mental health and well-being of LGBTQ+ individuals.",
"Allies of the LGBTQ+ community should work to combat homophobia wherever they encounter it.",
"Homophobia is a form of prejudice that has no place in a just and equitable society.",
"Homophobia often stems from a lack of understanding or empathy for the experiences of LGBTQ+ individuals.",
"Homophobia can manifest in many different ways, from derogatory language to physical violence to exclusion from certain spaces.",
"Homophobia is not just a problem for LGBTQ+ individuals, but for society as a whole.",
"By standing up against homophobia, we can create a world where everyone is free to love who they choose.",
"Homophobia is not only harmful, it is also illogical and unjustified."
]
labels = [1,1,1,0,1,1,1,1,1,1]


test = sentences
labels = labels
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Empty DataFrame
# Columns: []
# Index: []

# %%
# !pip install nlpaug

# %%
import pandas as pd
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.char as nac
import random

data = test_df.copy()
syn_aug = naw.SynonymAug(aug_src='wordnet')
lis = []
for index, row in data.iterrows():
    text = syn_aug.augment(row['text'], n=1)
    lis.extend(list(zip(text)))
tf = pd.DataFrame(lis, columns=['Changed_text'])

data = data.reset_index(drop=True)
tf = tf.reset_index(drop=True)

combined_data = pd.concat([data, tf], axis=1)
combined_data
# Out:
#                                                    text  labels  \
# 0                 This is an alu puntainga karumo chiii       2
# 1     Just thinking about it, if there is a psycho, ...       0
# 2     You can see the boy in the shape of a boy.. Pa...       1
# 3     third polygamists, those who eat manlike indiv...       2
# 4     {Singal tee machi u tube} Like Chanel, can you...       0
# ...                                                 ...     ...
# 1773  She acts very nice. Deoxyadenosine monophospha...       2
# 1774                           Malini sister is awesome       0
# 1775  It is acceptable in our culture               ...       0
# 1776  Having no word to describe but I seen multiple...       0
# 1777  7:42 - Seeing this sister talking peacefully b...       0
#
#                                            Changed_text
# 0                 This be an alu puntainga karumo chiii
# 1     Barely imagine astir it, if there personify a ...
# 2     You hind end see the boy in the soma of a boy....
# 3     3rd polygamists, those world health organizati...
# 4     { Singal tee machi u tube} Like Chanel, can yo...
# ...                                                 ...
# 1773  She play very nice. Deoxyadenosine monophospha...
# 1774                             Malini sister be awful
# 1775            It is satisfactory in our acculturation
# 1776  Having no word to describe but I seen multiple...
# 1777  7: 42 - Seeing this sister talking peacefully ...
#
# [1778 rows x 3 columns]

# %%
test = combined_data['Changed_text'].tolist()
org = combined_data['text'].tolist()
labels = combined_data['labels'].tolist()

combined_data['Changed_text_labels'], _ = model.predict(test)
combined_data['text_labels'], _ = model.predict(org)


from sklearn.metrics import accuracy_score
sim = accuracy_score(combined_data['Changed_text_labels'], combined_data['text_labels'])

print("similarity in predection score:",sim)
combined_data[combined_data['Changed_text_labels'] != combined_data['text_labels']]
# Out:
#   0%|          | 0/1778 [00:00<?, ?it/s]
#   0%|          | 0/56 [00:00<?, ?it/s]
#   0%|          | 0/1778 [00:00<?, ?it/s]
#   0%|          | 0/56 [00:00<?, ?it/s]
# similarity in predection score: 0.8340832395950506
#                                                    text  labels  \
# 2     You can see the boy in the shape of a boy.. Pa...       1
# 4     {Singal tee machi u tube} Like Chanel, can you...       0
# 5                                      That's good girl       0
# 13    This stray dog ​​may not have been born before...       1
# 20                                           Not she he       0
# ...                                                 ...     ...
# 1748  You need to be aware of the people who are att...       0
# 1766  There is a gay lesbian combination in every li...       0
# 1767  Transgenders have a good heart...these women d...       0
# 1771  I appreciate your open talk.in reality how man...       0
# 1774                           Malini sister is awesome       0
#
#                                            Changed_text  Changed_text_labels  \
# 2     You hind end see the boy in the soma of a boy....                    1
# 4     { Singal tee machi u tube} Like Chanel, can yo...                    1
# 5                       That ' s proficient young woman                    2
# 13    This isolated frankfurter ​ ​ crataegus laevig...                    2
# 20                                           Non she he                    2
# ...                                                 ...                  ...
# 1748  You demand to constitute aware of the mass who...                    1
# 1766  There is a gay lesbian combination in every li...                    1
# 1767  Transgenders make a good heart and soul. .. th...                    1
# 1771  Ane revalue your open talk. in world how many ...                    1
# 1774                             Malini sister be awful                    1
#
#       text_labels
# 2               0
# 4               0
# 5               0
# 13              1
# 20              0
# ...           ...
# 1748            0
# 1766            0
# 1767            0
# 1771            0
# 1774            0
#
# [295 rows x 5 columns]

# %%
test = combined_data['Changed_text'].tolist()
labels = combined_data['labels'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})
mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/1778 [00:00<?, ?it/s]
#   0%|          | 0/56 [00:00<?, ?it/s]
#                                                   text  true_label  \
# 0    Barely imagine astir it, if there personify a ...           0
# 1    { Singal tee machi u tube} Like Chanel, can yo...           0
# 2                      That ' s proficient young woman           0
# 3    This isolated frankfurter ​ ​ crataegus laevig...           1
# 4    Consistence comprise female. .. Simply encepha...           2
# ..                                                 ...         ...
# 321  You demand to constitute aware of the mass who...           0
# 322  There is a gay lesbian combination in every li...           0
# 323  Transgenders make a good heart and soul. .. th...           0
# 324  Ane revalue your open talk. in world how many ...           0
# 325                             Malini sister be awful           0
#
#      predicted_label
# 0                  1
# 1                  1
# 2                  2
# 3                  2
# 4                  1
# ..               ...
# 321                1
# 322                1
# 323                1
# 324                1
# 325                1
#
# [326 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.92      0.65      0.77       599
#   homophobic       0.75      0.83      0.79       598
#  transphobic       0.82      0.97      0.89       581
#
#     accuracy                           0.82      1778
#    macro avg       0.83      0.82      0.81      1778
# weighted avg       0.83      0.82      0.81      1778

# %%
import pandas as pd
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.char as nac
import random

data = test_df.copy()
char_aug = nac.RandomCharAug(action="insert")
lis = []
for index, row in data.iterrows():
    text = char_aug.augment(row['text'], n=1)
    lis.extend(list(zip(text)))
tf = pd.DataFrame(lis, columns=['Changed_text'])

data = data.reset_index(drop=True)
tf = tf.reset_index(drop=True)

combined_data = pd.concat([data, tf], axis=1)
combined_data
# Out:
#                                                    text  labels  \
# 0                 This is an alu puntainga karumo chiii       2
# 1     Just thinking about it, if there is a psycho, ...       0
# 2     You can see the boy in the shape of a boy.. Pa...       1
# 3     third polygamists, those who eat manlike indiv...       2
# 4     {Singal tee machi u tube} Like Chanel, can you...       0
# ...                                                 ...     ...
# 1773  She acts very nice. Deoxyadenosine monophospha...       2
# 1774                           Malini sister is awesome       0
# 1775  It is acceptable in our culture               ...       0
# 1776  Having no word to describe but I seen multiple...       0
# 1777  7:42 - Seeing this sister talking peacefully b...       0
#
#                                            Changed_text
# 0           TShims is an alu puntainga ka3rulmo chiDiMi
# 1     J5usit thinRkiMnDg about it, if there is a Gps...
# 2     You can see the boy in the psha+pe of a boy. ....
# 3     thilrkd polygamists, those who eat manql&ikje ...
# 4     { SgingHal tee Fmauchi u tu0bpe} BLikce ChaMne...
# ...                                                 ...
# 1773  She acts very nice. DeoTxyaYdenlosYin!e monoph...
# 1774                       MUalin#i si_st0er is awesome
# 1775              It is acAc^eptRable in our cuvltcu%re
# 1776  Having no word to describe but I seen multiple...
# 1777  7: 42 - Seeing _thHis sister tHaMlki4ng peacef...
#
# [1778 rows x 3 columns]

# %%
test = combined_data['Changed_text'].tolist()
org = combined_data['text'].tolist()
labels = combined_data['labels'].tolist()

combined_data['Changed_text_labels'], _ = model.predict(test)
combined_data['text_labels'], _ = model.predict(org)


from sklearn.metrics import accuracy_score
sim = accuracy_score(combined_data['Changed_text_labels'], combined_data['text_labels'])

print("similarity in predection score:",sim)
combined_data[combined_data['Changed_text_labels'] != combined_data['text_labels']]
# Out:
#   0%|          | 0/1778 [00:00<?, ?it/s]
#   0%|          | 0/56 [00:00<?, ?it/s]
#   0%|          | 0/1778 [00:00<?, ?it/s]
#   0%|          | 0/56 [00:00<?, ?it/s]
# similarity in predection score: 0.6991001124859393
#                                                    text  labels  \
# 0                 This is an alu puntainga karumo chiii       2
# 2     You can see the boy in the shape of a boy.. Pa...       1
# 4     {Singal tee machi u tube} Like Chanel, can you...       0
# 5                                      That's good girl       0
# 7     For SSC IMD 2017 expected cut off and other go...       0
# ...                                                 ...     ...
# 1761                                  Yes, look at you?       0
# 1766  There is a gay lesbian combination in every li...       0
# 1767  Transgenders have a good heart...these women d...       0
# 1772                Aravanis embody societal ruiner, ..       2
# 1773  She acts very nice. Deoxyadenosine monophospha...       2
#
#                                            Changed_text  Changed_text_labels  \
# 0           TShims is an alu puntainga ka3rulmo chiDiMi                    0
# 2     You can see the boy in the psha+pe of a boy. ....                    1
# 4     { SgingHal tee Fmauchi u tu0bpe} BLikce ChaMne...                    1
# 5                                That ' s gQolod girr2l                    2
# 7     For SSC IMD i201M7 exYpwe!cted cut off and obt...                    1
# ...                                                 ...                  ...
# 1761                                Yes, l)o6ok at you?                    1
# 1766  There is a gay lesbian combination in e%v+ery ...                    1
# 1767  Transgenders h)avSe a IgooQd heart. .. Hthe%se...                    1
# 1772        Arava#ntifs embody socWielta2l ruinmejr, ..                    1
# 1773  She acts very nice. DeoTxyaYdenlosYin!e monoph...                    1
#
#       text_labels
# 0               2
# 2               0
# 4               0
# 5               0
# 7               0
# ...           ...
# 1761            0
# 1766            0
# 1767            0
# 1772            2
# 1773            2
#
# [535 rows x 5 columns]

# %%
test = combined_data['Changed_text'].tolist()
labels = combined_data['labels'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})
mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/1778 [00:00<?, ?it/s]
#   0%|          | 0/56 [00:00<?, ?it/s]
#                                                   text  true_label  \
# 0          TShims is an alu puntainga ka3rulmo chiDiMi           2
# 1    J5usit thinRkiMnDg about it, if there is a Gps...           0
# 2    { SgingHal tee Fmauchi u tu0bpe} BLikce ChaMne...           0
# 3                               That ' s gQolod girr2l           0
# 4    For SSC IMD i201M7 exYpwe!cted cut off and obt...           0
# ..                                                 ...         ...
# 557                                Yes, l)o6ok at you?           0
# 558  There is a gay lesbian combination in e%v+ery ...           0
# 559  Transgenders h)avSe a IgooQd heart. .. Hthe%se...           0
# 560        Arava#ntifs embody socWielta2l ruinmejr, ..           2
# 561  She acts very nice. DeoTxyaYdenlosYin!e monoph...           2
#
#      predicted_label
# 0                  0
# 1                  1
# 2                  1
# 3                  2
# 4                  1
# ..               ...
# 557                1
# 558                1
# 559                1
# 560                1
# 561                1
#
# [562 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.83      0.52      0.64       599
#   homophobic       0.58      0.81      0.67       598
#  transphobic       0.75      0.72      0.73       581
#
#     accuracy                           0.68      1778
#    macro avg       0.72      0.68      0.68      1778
# weighted avg       0.72      0.68      0.68      1778
