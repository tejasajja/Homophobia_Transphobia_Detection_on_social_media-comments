# %%
# !pip install transformers
# !pip install -U -q PyDrive
# !pip install simpletransformers
# !pip freeze | grep simpletransformers

# %%
import pandas as pd
df=pd.read_csv('/content/eng_3_train.tsv', delimiter='\t') 
df=df[["text", "category"]]
df = df.dropna()
df_dev=pd.read_csv('/content/eng_3_dev.tsv', delimiter='\t') 
df_dev=df_dev[["text", "category"]]
df_dev = df_dev.dropna()
df_test=pd.read_csv('/content/eng_3_test.tsv', delimiter='\t')
df_test = df_test.rename(columns={'text                        ': 'text'}) 
df_test = df_test.dropna()

# %%
import pandas as pd
tam_df=pd.read_csv('/content/tam_3_train.tsv', delimiter='\t') 
tam_df=tam_df[["text", "category"]]
tam_df = tam_df.dropna()
tam_df_dev=pd.read_csv('/content/tam_3_dev.tsv', delimiter='\t') 
tam_df_dev=tam_df_dev[["text", "category"]]
tam_df_dev = tam_df_dev.dropna()
tam_df_test=pd.read_csv('/content/tam_3_test.tsv', delimiter='\t')
tam_df_test = tam_df_test.rename(columns={'text                        ': 'text'}) 
tam_df_test = tam_df_test.dropna()

# %%
etdf=pd.read_csv('/content/eng_tam_train.tsv', delimiter='\t') 
etdf=etdf[["text", "category"]]
etdf = etdf.dropna()
etdf_dev=pd.read_csv('/content/eng_tam_dev.tsv', delimiter='\t') 
etdf_dev=etdf_dev[["text", "category"]]
etdf_dev = etdf_dev.dropna()
etdf_test=pd.read_csv('/content/eng_tam_test.tsv', delimiter='\t') 
etdf_test = etdf_test.dropna()

# %%
tedf=pd.read_csv('/content/tam_eng_train.tsv', delimiter='\t') 
tedf=tedf[["text", "category"]]
tedf = tedf.dropna()
tedf_dev=pd.read_csv('/content/tam_eng_dev.tsv', delimiter='\t') 
tedf_dev=tedf_dev[["text", "category"]]
tedf_dev = tedf_dev.dropna()
tedf_test=pd.read_csv('/content/tam_eng_test.tsv', delimiter='\t') 
tedf_test = tedf_test.dropna()

# %%
teldf=pd.read_csv('/content/eng_tel_train.tsv', delimiter='\t') 
teldf=teldf[["text", "category"]]
teldf = teldf.dropna()
teldf_dev=pd.read_csv('/content/eng_tel_dev.tsv', delimiter='\t') 
teldf_dev=teldf_dev[["text", "category"]]
teldf_dev = teldf_dev.dropna()
teldf_test=pd.read_csv('/content/eng_tel_test.tsv', delimiter='\t') 
teldf_test = teldf_test.dropna()

# %%
hieldf=pd.read_csv('/content/eng_hin_train.tsv', delimiter='\t') 
hieldf=hieldf[["text", "category"]]
hieldf = hieldf.dropna()
hieldf_dev=pd.read_csv('/content/eng_hin_dev.tsv', delimiter='\t') 
hieldf_dev=hieldf_dev[["text", "category"]]
hieldf_dev = hieldf_dev.dropna()
hieldf_test=pd.read_csv('/content/eng_hin_test.tsv', delimiter='\t') 
hieldf_test = hieldf_test.dropna()

# %%
mleldf=pd.read_csv('/content/eng_ml_train.tsv', delimiter='\t') 
mleldf=mleldf[["text", "category"]]
mleldf = mleldf.dropna()
mleldf_dev=pd.read_csv('/content/eng_ml_dev.tsv', delimiter='\t') 
mleldf_dev=mleldf_dev[["text", "category"]]
mleldf_dev = mleldf_dev.dropna()
mleldf_test=pd.read_csv('/content/eng_ml_test.tsv', delimiter='\t') 
mleldf_test = mleldf_test.dropna()

# %%
tamteldf=pd.read_csv('/content/tam_tel_train.tsv', delimiter='\t') 
tamteldf=tamteldf[["text", "category"]]
tamteldf = tamteldf.dropna()
tamteldf_dev=pd.read_csv('/content/tam_tel_dev.tsv', delimiter='\t') 
tamteldf_dev=tamteldf_dev[["text", "category"]]
tamteldf_dev = tamteldf_dev.dropna()
tamteldf_test=pd.read_csv('/content/tam_tel_test.tsv', delimiter='\t') 
tamteldf_test = tamteldf_test.dropna()

# %%
tamhieldf=pd.read_csv('/content/tam_hin_train.tsv', delimiter='\t') 
tamhieldf=tamhieldf[["text", "category"]]
tamhieldf = tamhieldf.dropna()
tamhieldf_dev=pd.read_csv('/content/tam_hin_dev.tsv', delimiter='\t') 
tamhieldf_dev=tamhieldf_dev[["text", "category"]]
tamhieldf_dev = tamhieldf_dev.dropna()
tamhieldf_test=pd.read_csv('/content/tam_hin_test.tsv', delimiter='\t') 
tamhieldf_test = tamhieldf_test.dropna()

# %%
tammleldf=pd.read_csv('/content/tam_ml_train.tsv', delimiter='\t') 
tammleldf=tammleldf[["text", "category"]]
tammleldf = tammleldf.dropna()
tammleldf_dev=pd.read_csv('/content/tam_ml_dev.tsv', delimiter='\t') 
tammleldf_dev=tammleldf_dev[["text", "category"]]
tammleldf_dev = tammleldf_dev.dropna()
tammleldf_test=pd.read_csv('/content/tam_ml_test.tsv', delimiter='\t') 
tammleldf_test = tammleldf_test.dropna()

# %%
train = pd.concat([df, tedf,tam_df,etdf,teldf,hieldf,mleldf,tamteldf,tammleldf])
valid = pd.concat([df_dev, tedf_dev,tam_df_dev,etdf_dev,teldf_dev,hieldf_dev,mleldf_dev,tamteldf_dev,tamhieldf_dev,tammleldf_dev])
test = pd.concat([df_test, tedf_test,tam_df_test,etdf_test,teldf_test,hieldf_test,mleldf_test,tamteldf_test,tamhieldf_test,tammleldf_test])

# %%
concatenated = pd.concat([train,test,valid])

import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit

df = concatenated

X = df['text']
y = df['category']

testsplit = StratifiedShuffleSplit(n_splits=1, test_size=0.20, random_state=42)

train_val_idx, test_idx = next(testsplit.split(X, y))

X_train_val, X_test = X.iloc[train_val_idx], X.iloc[test_idx]
y_train_val, y_test = y.iloc[train_val_idx], y.iloc[test_idx]


validsplit = StratifiedShuffleSplit(n_splits=1, test_size=0.25, random_state=42)

train_idx, val_idx = next(validsplit.split(X_train_val, y_train_val))

X_train, X_val = X_train_val.iloc[train_idx], X_train_val.iloc[val_idx]
y_train, y_val = y_train_val.iloc[train_idx], y_train_val.iloc[val_idx]

train_df = pd.DataFrame({'text': X_train, 'category': y_train})
val_df = pd.DataFrame({'text': X_val, 'category': y_val})
test_df = pd.DataFrame({'text': X_test, 'category': y_test})

print(f'Training set shape: {train_df.shape}')
print(f'Validation set shape: {val_df.shape}')
print(f'Test set shape: {test_df.shape}')
# Out:
# Training set shape: (25185, 2)
# Validation set shape: (8396, 2)
# Test set shape: (8396, 2)

# %%
print(train_df['category'].value_counts())
print(val_df['category'].value_counts())
print(test_df['category'].value_counts())
# Out:
# Non-anti-LGBT+ content    21955
# Homophobic                 2620
# Transphobic                 610
# Name: category, dtype: int64
# Non-anti-LGBT+ content    7319
# Homophobic                 873
# Transphobic                204
# Name: category, dtype: int64
# Non-anti-LGBT+ content    7319
# Homophobic                 874
# Transphobic                203
# Name: category, dtype: int64

# %%
train_df['category'] = train_df['category'].replace('Non-anti-LGBT+ content', 'ally')
val_df['category'] = val_df['category'].replace('Non-anti-LGBT+ content', 'ally')
test_df['category'] = test_df['category'].replace('Non-anti-LGBT+ content', 'ally')

# %%
train_df['category'] = train_df['category'].replace('ally', 0)
train_df['category'] = train_df['category'].replace('Homophobic', 1)
train_df['category'] = train_df['category'].replace('Transphobic', 2)

# %%
val_df['category'] = val_df['category'].replace('ally', 0)
val_df['category'] = val_df['category'].replace('Homophobic', 1)
val_df['category'] = val_df['category'].replace('Transphobic', 2)

# %%
test_df['category'] = test_df['category'].replace('ally', 0)
test_df['category'] = test_df['category'].replace('Homophobic', 1)
test_df['category'] = test_df['category'].replace('Transphobic', 2)

# %%
train_df=train_df[["text", "category"]]
train_df = train_df.rename(columns={'text': 'text', 'category': 'labels'})
val_df=val_df[["text", "category"]]
val_df = val_df.rename(columns={'text': 'text', 'category': 'labels'})
test_df=test_df[["text", "category"]]
test_df = test_df.rename(columns={'text': 'text', 'category': 'labels'})

# %%
# !pip install emoji

# %%
import emoji
train_df['text'] = train_df['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))
val_df['text'] = val_df['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))
test_df['text'] = test_df['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))

# %% [markdown]
# Mbert on whole translated data

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs
import logging

logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

# define hyperparameter
train_args ={"reprocess_input_data": True,
             "overwrite_output_dir": True,
             "fp16":False,
             "num_train_epochs": 3,
             "max_seq_length": 128,
             "train_batch_size": 16,
             "eval_batch_size": 16,
             "logging_steps": 50,
             "save_steps": 2000,
             "learning_rate": 2e-5}

# Create a ClassificationModel
model = ClassificationModel(
    "xlmroberta", "xlm-roberta-base",
    num_labels=3,
    args=train_args
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'roberta.pooler.dense.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'roberta.pooler.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# /usr/local/lib/python3.9/dist-packages/simpletransformers/classification/classification_model.py:486: UserWarning: use_multiprocessing automatically disabled as xlmroberta fails when using multiprocessing for feature conversion.
#   warnings.warn(

# %%
model.train_model(train_df)
# Out:
# Epoch:   0%|          | 0/3 [00:00<?, ?it/s]
# Running Epoch 0 of 3:   0%|          | 0/1575 [00:00<?, ?it/s]
# Running Epoch 1 of 3:   0%|          | 0/1575 [00:00<?, ?it/s]
# Running Epoch 2 of 3:   0%|          | 0/1575 [00:00<?, ?it/s]
# (4725, 0.28906329246651796)

# %%
model.save_model('/content/xlm-mbert_model')

# %%
from sklearn.metrics import f1_score, accuracy_score

def f1_multiclass(labels, preds):
    return f1_score(labels, preds, average='macro')
result, model_outputs, wrong_predictions = model.eval_model(val_df, f1=f1_multiclass, acc=accuracy_score)
result
# Out:
#   0%|          | 0/8396 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/525 [00:00<?, ?it/s]
# {'mcc': 0.677307296234697,
#  'f1': 0.7556442718946713,
#  'acc': 0.9310385898046689,
#  'eval_loss': 0.2778161929891489}

# %%
test_df
# Out:
#                                                    text  labels
# 1510  Part 2 When will pro come my rose rose rose my...       0
# 189      பெண்மை புதுமை முதுமை தாய்மை அவன் அல்ல அவள்தான்       0
# 2621               ఇది చాలా తప్పు. కోడ్‌కి డిటెస్టపైల్.       1
# 1829                                    S, మీరు చూడండి?       0
# 755   What is Madan Dravidian? Dravidam. What happen...       0
# ...                                                 ...     ...
# 556   Even if nature does not change, great dangers ...       1
# 1209  स्प्र्र अन्ना दिल को छू लेने वाली... सभी के लि...       0
# 692   सौम्या नारायण कृपया बेवकूफ संस्कृति के बजाय प्...       0
# 2648  இன்னும் கல்லகாதல் மற்றும் கற்பலிப்பு  அதிகரிக்...       1
# 2465                           కన్నీళ్లతో ఐస్ పైలట్_వేట       0
#
# [8396 rows x 2 columns]

# %%
test = test_df['text'].tolist()
labels = test_df['labels'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/8396 [00:00<?, ?it/s]
#   0%|          | 0/525 [00:00<?, ?it/s]
#                                                   text  true_label  \
# 0                 ఇది చాలా తప్పు. కోడ్‌కి డిటెస్టపైల్.           1
# 1                     नन परमचर्यम पर निर्भर थीं। आप...           1
# 2    நான் கொஞ்சம் நேரம் உன் பேச்ச கேட்டேன், என்னயவே...           1
# 3                 സമൂഹത്തെ മാറ്റാത്തതിൽ നാം ലജ്ജിക്കണം           1
# 4    దోఝా, కైతట్టల్ కైతట్టల్ కైతట్టల్ కైలు; ప్రోత్స...           0
# ..                                                 ...         ...
# 564                          நான் lgbt ஐ ஆதரிக்கிறேன்.           0
# 565                        Your life is in your hands.           1
# 566                           ഇത് പണം തട്ടുന്ന സംഘമല്ല           2
# 567  ഒരു പുരുഷനും പെണ്ണിനൊപ്പം ജീവിക്കാൻ ആഗ്രഹിക്കാ...           1
# 568  weird தமிழன்  அறிவை கொஞ்சம் வளர்த்துக்கோங்க  ஓ...           1
#
#      predicted_label
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  1
# ..               ...
# 564                1
# 565                0
# 566                0
# 567                0
# 568                0
#
# [569 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.96      0.97      0.96      7319
#   homophobic       0.78      0.67      0.72       874
#  transphobic       0.63      0.58      0.60       203
#
#     accuracy                           0.93      8396
#    macro avg       0.79      0.74      0.76      8396
# weighted avg       0.93      0.93      0.93      8396

# %% [markdown]
# #testing with Hindi

# %%
o_test=pd.read_csv('/content/eng_hin_test.tsv', delimiter='\t') 
o_test = o_test.dropna()
e_test=pd.read_csv('/content/tam_hin_test.tsv', delimiter='\t')
e_test=e_test[["text", "category"]] 
e_test = e_test.dropna()

# %%
test_ml = pd.concat([o_test,e_test])
len(test_ml)
# Out:
# 1819

# %%
test_ml['category'] = test_ml['category'].replace('Non-anti-LGBT+ content', 'ally')
test_ml['category'] = test_ml['category'].replace('ally', 0)
test_ml['category'] = test_ml['category'].replace('Homophobic', 1)
test_ml['category'] = test_ml['category'].replace('Transphobic', 2)

# %%
test_ml=test_ml[["text", "category"]]
test_ml = test_ml.rename(columns={'text': 'text', 'category': 'labels'})

# %%
test_ml['text'] = test_ml['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))

# %%
test = test_ml['text'].tolist()
labels = test_ml['labels'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/1819 [00:00<?, ?it/s]
#   0%|          | 0/114 [00:00<?, ?it/s]
#                                                  text  true_label  \
# 0   संस्कृति की बात करने वालों के लिए, शादी से पहल...           0
# 1   हम सभी जानते हैं कि ये ड्रिंक्स सेहत के लिए बि...           0
# 2                      पुलिस को उन्हें सजा देनी चाहिए           1
# 3   निर्देशक सर pls गे रिपेंट अगुरा मारी फिल्म एडुंगा           1
# 4   हम रेलवे पुलिस हैं ओह, मुझे खेद है कि वे सो रह...           1
# ..                                                ...         ...
# 93    गुगन बालराज समन चंदा साइंटिफिक?? लानत है तुम पर           1
# 94  प्राकृतिक मनुष्य बनाने के लिए,,; आदमी ने पैसा ...           0
# 95                                      क्रोधित_चेहरा           1
# 96    अनाथ क्यों बड़े होते हैं आपकी तरह लेस्बियन, गे?           1
# 97  आप बौद्धिक रूप से बोलने के बारे में सोचते हैं ...           1
#
#     predicted_label
# 0                 1
# 1                 1
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 93                0
# 94                1
# 95                0
# 96                0
# 97                0
#
# [98 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.96      0.98      0.97      1579
#   homophobic       0.84      0.73      0.78       194
#  transphobic       0.69      0.72      0.70        46
#
#     accuracy                           0.95      1819
#    macro avg       0.83      0.81      0.82      1819
# weighted avg       0.94      0.95      0.94      1819

# %% [markdown]
# # testing with Telugu

# %%
o_test=pd.read_csv('/content/eng_tel_test.tsv', delimiter='\t') 
o_test = o_test.dropna()
e_test=pd.read_csv('/content/tam_tel_test.tsv', delimiter='\t')
e_test=e_test[["text", "category"]] 
e_test = e_test.dropna()

# %%
test_ml = pd.concat([o_test,e_test])
len(test_ml)
# Out:
# 1819

# %%
test_ml['category'] = test_ml['category'].replace('Non-anti-LGBT+ content', 'ally')
test_ml['category'] = test_ml['category'].replace('ally', 0)
test_ml['category'] = test_ml['category'].replace('Homophobic', 1)
test_ml['category'] = test_ml['category'].replace('Transphobic', 2)

# %%
test_ml=test_ml[["text", "category"]]
test_ml = test_ml.rename(columns={'text': 'text', 'category': 'labels'})

# %%
test_ml['text'] = test_ml['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))

# %%
test = test_ml['text'].tolist()
labels = test_ml['labels'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/1819 [00:00<?, ?it/s]
#   0%|          | 0/114 [00:00<?, ?it/s]
#                                                  text  true_label  \
# 0   మీరు గంజాయి మరియు THC 'tetrahydrocannabinol సమ...           0
# 1                         పోలీసులు వారిని శిక్షించాలి           1
# 2   డైరెక్టర్ సర్ ప్లీస్ గే పశ్చాత్తాపపడండి అగురా ...           1
# 3   మేము రైల్వే పోలీసులు అయ్యో నన్ను క్షమించండి వా...           1
# 4     వారు ప్రకృతికి వ్యతిరేకం కాదు అది వారి స్వభావం.           0
# ..                                                ...         ...
# 90  గుగన్ బాల్రాజ్ సమన్ చందా శాస్త్రోక్తంగా?? నీ ఎ...           1
# 91                                        కోపంతో_ముఖం           1
# 92  అనాథలు మీలాగా లెస్బియన్‌గా, గేలుగా ఎందుకు పెరు...           1
# 93        మీరు తెలివిగా మాట్లాడాలని అనుకుంటున్నారు...           1
# 94                  ఏ అబ్బాయి కూడా అబ్బాయిగా ఉండకూడదు           0
#
#     predicted_label
# 0                 1
# 1                 0
# 2                 0
# 3                 0
# 4                 1
# ..              ...
# 90                0
# 91                0
# 92                2
# 93                0
# 94                1
#
# [95 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.96      0.99      0.97      1579
#   homophobic       0.86      0.73      0.79       194
#  transphobic       0.76      0.54      0.63        46
#
#     accuracy                           0.95      1819
#    macro avg       0.86      0.75      0.80      1819
# weighted avg       0.94      0.95      0.95      1819

# %% [markdown]
# # testing with Malyalam

# %%
o_test=pd.read_csv('/content/eng_ml_test.tsv', delimiter='\t') 
o_test = o_test.dropna()
e_test=pd.read_csv('/content/tam_ml_test.tsv', delimiter='\t')
e_test=e_test[["text", "category"]] 
e_test = e_test.dropna()

# %%
test_ml = pd.concat([o_test,e_test])
len(test_ml)
# Out:
# 1819

# %%
test_ml['category'] = test_ml['category'].replace('Non-anti-LGBT+ content', 'ally')
test_ml['category'] = test_ml['category'].replace('ally', 0)
test_ml['category'] = test_ml['category'].replace('Homophobic', 1)
test_ml['category'] = test_ml['category'].replace('Transphobic', 2)

# %%
test_ml=test_ml[["text", "category"]]
test_ml = test_ml.rename(columns={'text': 'text', 'category': 'labels'})

# %%
test_ml['text'] = test_ml['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))

# %%
test = test_ml['text'].tolist()
labels = test_ml['labels'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/1819 [00:00<?, ?it/s]
#   0%|          | 0/114 [00:00<?, ?it/s]
#                                                  text  true_label  \
# 0   ആ പാനീയങ്ങൾ ആരോഗ്യത്തിന് ഒട്ടും നല്ലതല്ലെന്ന് ...           0
# 1                             പോലീസ് അവരെ ശിക്ഷിക്കണം           1
# 2   7.33 മിനിറ്റിൽ നിങ്ങൾ പറഞ്ഞത് ശരിയായ കാര്യമാണ്...           0
# 3   ഞങ്ങൾ റെയിൽവേ പോലീസാണ് ഓ, ക്ഷമിക്കണം, അവർ ഉറങ്...           1
# 4   അവർ ആണും പെണ്ണുമല്ല..മാനസിക വിഭ്രാന്തിയുള്ള ചി...           1
# ..                                                ...         ...
# 74  ഈ ലോകത്തിലെ പ്രകൃതിദത്തമായ വസ്തുക്കളെ കാണുന്ന ...           0
# 75  Gay ah അവർ തെറ്റല്ല...ദൈവത്തിന്റെ കളി കൊണ്ടാണ്...           0
# 76                           ഇത് പണം തട്ടുന്ന സംഘമല്ല           2
# 77                                    രോഷാകുലമായ_മുഖം           1
# 78  നിങ്ങൾ ബുദ്ധിപരമായി സംസാരിക്കാൻ വിചാരിക്കുന്നു...           1
#
#     predicted_label
# 0                 1
# 1                 0
# 2                 1
# 3                 0
# 4                 0
# ..              ...
# 74                1
# 75                1
# 76                0
# 77                0
# 78                0
#
# [79 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.97      0.98      0.98      1579
#   homophobic       0.85      0.79      0.82       194
#  transphobic       0.83      0.76      0.80        46
#
#     accuracy                           0.96      1819
#    macro avg       0.89      0.84      0.86      1819
# weighted avg       0.96      0.96      0.96      1819

# %% [markdown]
# #testing with tamil

# %%
o_test=pd.read_csv('/content/eng_tam_test.tsv', delimiter='\t') 
o_test = o_test.dropna()
e_test=pd.read_csv('/content/tam_3_test.tsv', delimiter='\t')
e_test=e_test[["text", "category"]] 
e_test = e_test.dropna()

# %%
test_ml = pd.concat([o_test,e_test])

# %%
test_ml['category'] = test_ml['category'].replace('Non-anti-LGBT+ content', 'ally')
test_ml['category'] = test_ml['category'].replace('ally', 0)
test_ml['category'] = test_ml['category'].replace('Homophobic', 1)
test_ml['category'] = test_ml['category'].replace('Transphobic', 2)

# %%
test_ml=test_ml[["text", "category"]]
test_ml = test_ml.rename(columns={'text': 'text', 'category': 'labels'})

# %%
test_ml['text'] = test_ml['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))

# %%
test = test_ml['text'].tolist()
labels = test_ml['labels'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/1819 [00:00<?, ?it/s]
#   0%|          | 0/114 [00:00<?, ?it/s]
#                                                   text  true_label  \
# 0    எனது கருத்துக்கு பதிலளித்த நீங்கள் இருவரும் இத...           1
# 1    மனநோய் என்று நினைக்கிறேன். சென்று மருத்துவரை அ...           1
# 2    அந்த பானங்கள் ஆரோக்கியத்திற்கு நல்லதல்ல என்பதை...           0
# 3                   அவர்களை போலீசார் தண்டிக்க வேண்டும்           1
# 4    டைரக்டர் சார் ப்ளீஸ் கே தவம் ஆகுற மாரி படம் எட...           1
# ..                                                 ...         ...
# 118    இவ மூஞ்சி புண்டய பாரு ெபாட்ட கூதி enraged_face            1
# 119  மனிதன் செய்யகூடிய சகல காரியங்களுக்கும் நியாயதீ...           1
# 120  ஆண்மை இருந்தால் மட்டும்தான் ஆணாக இருந்தாலும் ஆ...           0
# 121     அறிவுபூர்வமாக பேசுவது என்ற நினைப்பு உனக்கு...            1
# 122  அருமை பேச்சு .இனிமையான குரல். கேள்விக்கேற்ற பத...           1
#
#      predicted_label
# 0                  0
# 1                  0
# 2                  1
# 3                  0
# 4                  0
# ..               ...
# 118                0
# 119                0
# 120                2
# 121                0
# 122                0
#
# [123 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.96      0.97      0.97      1579
#   homophobic       0.79      0.65      0.71       194
#  transphobic       0.60      0.70      0.65        46
#
#     accuracy                           0.93      1819
#    macro avg       0.78      0.77      0.78      1819
# weighted avg       0.93      0.93      0.93      1819

# %% [markdown]
# #testing with english

# %%
o_test=pd.read_csv('/content/tam_eng_test.tsv', delimiter='\t') 
o_test = o_test.dropna()
e_test=pd.read_csv('/content/eng_3_test.tsv', delimiter='\t')
e_test = e_test.rename(columns={'text                        ': 'text'})
#e_test=e_test[["text", "category"]] 
e_test = e_test.dropna()

# %%
test_ml = pd.concat([o_test,e_test])
test_ml
# Out:
#      Unnamed: 0                                               text  \
# 0           0.0        When each commanta was read and brought up.
# 1           1.0  Bro live a prosperous bouquet OK_hand OK_hand ...
# 2           2.0                             Jesus is a step sister
# 3           3.0                              Eyes are confused....
# 4           4.0  Come together Gay mean not sex it's love also ...
# ..          ...                                                ...
# 985         NaN  Looks like Karthik took advantage on Varun whe...
# 986         NaN  i am really crying pro😢😢😢😭😭😭😭😭😭               ...
# 987         NaN  They may be transgender but don't ever forgot ...
# 988         NaN  It is their own choice. I support them No doub...
# 989         NaN  Waited for a long time congrts team... such a ...
#
#                    category       ln
# 0    Non-anti-LGBT+ content  tam_eng
# 1    Non-anti-LGBT+ content  tam_eng
# 2    Non-anti-LGBT+ content  tam_eng
# 3    Non-anti-LGBT+ content  tam_eng
# 4    Non-anti-LGBT+ content  tam_eng
# ..                      ...      ...
# 985  Non-anti-LGBT+ content      NaN
# 986  Non-anti-LGBT+ content      NaN
# 987  Non-anti-LGBT+ content      NaN
# 988  Non-anti-LGBT+ content      NaN
# 989  Non-anti-LGBT+ content      NaN
#
# [1819 rows x 4 columns]

# %%
test_ml['category'] = test_ml['category'].replace('Non-anti-LGBT+ content', 'ally')
test_ml['category'] = test_ml['category'].replace('ally', 0)
test_ml['category'] = test_ml['category'].replace('Homophobic', 1)
test_ml['category'] = test_ml['category'].replace('Transphobic', 2)

# %%
test_ml=test_ml[["text", "category"]]
test_ml = test_ml.rename(columns={'text': 'text', 'category': 'labels'})

# %%
test_ml['text'] = test_ml['text'].apply(lambda x: emoji.demojize(x, delimiters=(" ", " ")))

# %%
test = test_ml['text'].tolist()
labels = test_ml['labels'].tolist()
predictions, _ = model.predict(test)

misclassified_records = []

for i in range(len(test)):
    if predictions[i] != labels[i]:
        misclassified_records.append({'text': test[i], 'true_label': labels[i], 'predicted_label': predictions[i]})

mis = pd.DataFrame(misclassified_records)
mis
# Out:
#   0%|          | 0/1819 [00:00<?, ?it/s]
#   0%|          | 0/114 [00:00<?, ?it/s]
#                                                  text  true_label  \
# 0                    pranesh G you are a transgender.           2
# 1               Many extroverts say this is unnatural           0
# 2   Let the country and the people of the country ...           0
# 3                                     Che Kanaravi ..           1
# 4   Ulagama Alivu Arambam Urudi heard this Oth Kan...           1
# ..                                                ...         ...
# 67  Anyone watched My son is gay ?                ...           0
# 68  I'm sharing my experience pls read it, two tra...           2
# 69  Common people cannot understand the DNA abbera...           0
# 70  First of all, i wanna know onething. Do you th...           1
# 71  Friendship s friendship.dont make it as sexual...           1
#
#     predicted_label
# 0                 0
# 1                 1
# 2                 1
# 3                 0
# 4                 2
# ..              ...
# 67                1
# 68                0
# 69                1
# 70                0
# 71                0
#
# [72 rows x 3 columns]

# %%
from sklearn.metrics import classification_report
target_names = ['ally', 'homophobic', 'transphobic']
print(classification_report(labels, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         ally       0.97      0.99      0.98      1579
#   homophobic       0.88      0.80      0.84       194
#  transphobic       0.80      0.78      0.79        46
#
#     accuracy                           0.96      1819
#    macro avg       0.88      0.86      0.87      1819
# weighted avg       0.96      0.96      0.96      1819
